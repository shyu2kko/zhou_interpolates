# %%
import neuromaps.datasets

seroto = neuromaps.datasets.fetch_annotation(source="beliveau2017", space='fsaverage')

# %%
receptor_names = ['5HT1A', '5HT1B', '5HT2A', '5HT4', '5HTT']
tracer_names = ['cumi101', 'p943', 'cimbi36', 'sb207145', 'dasb']
gene_symbols = ['HTR1A', 'HTR1B', 'HTR2A', 'HTR4', 'SLC6A4']

import pandas as pd

mappings = pd.DataFrame([receptor_names, tracer_names, gene_symbols], index = ['receptor', 'tracer', 'gene']).T

# %%
mappings.to_csv('/home/bic/yiguz/projects/beliveau2017_serotonergic_names_mappings.csv')

# %%
import abagen
import os
os.environ['ABAGEN_DATA'] = "/home/bic/yiguz/projects/data/gene_expression/"
e, m = abagen.get_samples_in_mask(verbose = 1, ibf_threshold = 0.1)
# Out:
# INFO: Group-level atlas provided; using MNI coords for tissue samples
# INFO: Reannotating probes with information from Arnatkevic̆iūtė et al., 2019, NeuroImage
# INFO: Filtering probes with intensity-based threshold of 0.1
# INFO: 36743 probes survive intensity-based filtering
# INFO: Reducing probes indexing same gene with method: diff_stability
# /poolz0/yiguz/anaconda3/envs/py311/lib/python3.11/site-packages/abagen/probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# /poolz0/yiguz/anaconda3/envs/py311/lib/python3.11/site-packages/abagen/probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# ...

# %%
# initiate a new dataframe to compile the expressions and then save it

serotonergic = pd.DataFrame([None])

for gene_symbol in gene_symbols:

    if serotonergic.empty: serotonergic = e[gene_symbol]
    else: serotonergic = pd.concat([ serotonergic, e[gene_symbol] ], axis = 1)

serotonergic = serotonergic.drop(0, axis = 0)
serotonergic = serotonergic.drop(0, axis = 1)

# %%
joblib.dump((serotonergic,m), '/home/bic/yiguz/projects/interpolate/data/serotonergic_gene_expression.pkl')
# Out:
# ['/home/bic/yiguz/projects/interpolate/data/serotonergic_gene_expression.pkl']

# %%
joblib.load('/home/bic/yiguz/projects/interpolate/data/serotonergic_gene_expression.pkl')
# Out:
# (              HTR1A     HTR1B     HTR2A      HTR4    SLC6A4
#  594        0.536634  0.626038  0.820641  0.615009  0.069626
#  2985       0.582885  0.739718  0.743913  0.561042  0.377163
#  2801       0.445033  0.616996  0.358333  0.184073  0.895911
#  2273       0.153321  0.705782  0.151018  0.119099  0.690837
#  2785       0.530273  0.453279  0.375077  0.717007  0.593124
#  ...             ...       ...       ...       ...       ...
#  159439039  0.498509  0.906817  0.370169  0.568361  0.074891
#  159438991  0.133073  1.000000  0.472454  0.121800  0.511002
#  159438975  0.116972  0.186219  0.450309  0.025326  0.749139
#  159438959  0.064461  0.179521  0.346671  0.186158  0.105908
#  159438943  0.008104  0.115773  0.411020  0.171338  0.000000
#
#  [3466 rows x 5 columns],
#                     x          y          z
#  well_id
#  594         6.281693 -26.769456  46.030920
#  2985       29.463218  17.371072  -6.841868
#  2801       30.916352 -19.971094  12.528056
# ...

# %%
# interpolate to fsLR-4k one by one
