# %%
import sys
sys.path.append("../")

from config import *
from figs_config import *
import wrappers
from interpmodules import helpers, metrics
# Out:
# Loaded aesthetics module

# %% [markdown]
# # I. Gaussian Random Fields

# %% [markdown]
# This section contains code for visualizing **GRF instances**, **sampling regimes**, conducting **variography**, and **linear regression**

# %% [markdown]
# ## _Data specs_

# %%
space = 'fsLR-4k'
datasource='grf'
geometry = 'sphere'
strategy = 'random'
niters = 100

# %% [markdown]
# ## _Colour scheme_

# %% [markdown]
# * main colour gradient

# %%
# main colour maps
gnrd,_ = three_colours_gradient(lo=plt.cm.Blues(0.7), mid=plt.cm.YlOrBr(0.1), hi=plt.cm.Oranges(0.6), plot=False)
show_colour_scheme(gnrd, "GNRD")

# %% [markdown]
# * discrete palette for percentages

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get an existing colormap and sample a segment
lincmap = plt.get_cmap('Blues')
range_colours = lincmap(np.linspace(0.4, .7, len(test_percentages)))
sns.color_palette(range_colours)
# Out:
# [(0.5796078431372549, 0.7701960784313725, 0.8737254901960784),
#  (0.41708573625528644, 0.6806305267204922, 0.8382314494425221),
#  (0.2909803921568628, 0.5945098039215686, 0.7890196078431373),
#  (0.1791464821222607, 0.49287197231833907, 0.7354248366013072)]

# %% [markdown]
# * discrete palette for ranges

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get an existing colormap and sample a segment
lincmap = plt.get_cmap('YlOrBr')
pct_colours = lincmap(np.linspace(0.3, .6, len(test_percentages)))
sns.color_palette(pct_colours)
# Out:
# [(0.996078431372549, 0.8434755863129565, 0.4691580161476355),
#  (0.996078431372549, 0.7349019607843138, 0.28),
#  (0.9949711649365629, 0.5974778931180315, 0.15949250288350636),
#  (0.939607843137255, 0.4713725490196078, 0.09490196078431372)]

# %%
from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=pct_colours[pi], label=f"{p}%")
    for pi, p in enumerate(test_percentages)
]

plt.legend(handles=legend_elements, loc='upper right', frameon=False, ncol = len(test_percentages), bbox_to_anchor=(0, 1.25))
plt.savefig(projdir + '/figs/main/grf_pct_colours.svg')

# %%
from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=range_colours[ri], label=f"range={r}")
    for ri, r in enumerate(test_ranges)
]

plt.legend(handles=legend_elements, loc='upper right', frameon=False, ncol = len(test_ranges), bbox_to_anchor=(0, 1.25))
plt.savefig(projdir + '/figs/main/grf_range_colours.svg')

# %% [markdown]
# ## GRF instances

# %% [markdown]
# ### Data and sampling

# %% [markdown]
# * load data

# %%
import joblib
sphere_mesh = joblib.load(projdir + '/data/fsLR-4k_sphere_grf.pkl')

# %% [markdown]
# * visualize each instance from 25 to 100

# %%
import copy
import pyvista as pv

pl = pv.Plotter(shape = (1,len(np.arange(25,105,5))), window_size = (1500,100))

for ri, r in enumerate(np.arange(25,105,5)):
    pl.subplot(0,ri)
    tmp_mesh = copy.deepcopy(sphere_mesh)
    pl.add_mesh(tmp_mesh, scalars = str(r), cmap = gnrd, **mesh_aes)
    pl.add_text(str(r), position = "lower_edge", font = "courier", font_size = 8)
    pl.camera_position = 'yz'
pl.show(jupyter_backend='static')
#pl.save_graphic(projdir + "/figs/main/grf_instances.svg")
# Out:
# <PIL.Image.Image image mode=RGB size=1500x100>

# %%
import copy
import pyvista as pv

pl = pv.Plotter(shape = (1,len(test_ranges)), window_size = (400,100))

for ri, r in enumerate(test_ranges):
    pl.subplot(0,ri)
    tmp_mesh = copy.deepcopy(sphere_mesh)
    pl.add_mesh(tmp_mesh, scalars = str(r), cmap = gnrd, **mesh_aes)
    pl.add_text(str(r), position = "lower_edge", font = "courier", font_size = 8)
    pl.camera_position = 'yz'
pl.show(jupyter_backend='static')
#pl.save_graphic(projdir + "/figs/main/grf_instances.svg")
# Out:
# <PIL.Image.Image image mode=RGB size=400x100>

# %% [markdown]
# * visualize 25, 50, 75 and 100

# %%
import copy
import pyvista as pv

pl = pv.Plotter(shape = (1,len(test_ranges)), window_size = (400,100))

ps = [7, 7, 6, 5]
for pi, p in enumerate(test_percentages):

    desc, sampling = joblib.load(projdir + f'/data/sampling/fsLR-4k_sphere_samp-fibonacci_pct-{p}.pkl')
    known_coords, known_verts ,_,_ = sampling
    
    pl.subplot(0,pi)
    tmp_mesh = copy.deepcopy(sphere_mesh)
    pl.add_mesh(tmp_mesh, color = 'dimgray', opacity = .7, **mesh_aes)
    pl.add_points(known_coords[:,:,0], scalars = sphere_mesh['50'][known_verts[:,0].astype(int)], \
                  point_size = ps[pi]/2, cmap = gnrd, show_scalar_bar=False, **point_aes)
    pl.add_text(str(p)+"%", position = "lower_edge", font = "courier", font_size = 8)
    pl.camera_position = 'yz'
pl.show(jupyter_backend='static')
pl.save_graphic(projdir + "/figs/main/grf_sparse_instances.svg")
# Out:
# <PIL.Image.Image image mode=RGB size=400x100>

# %% [markdown]
# ### Supplemental: Toy covariates

# %%
import wrappers

Yk0, yk1 = wrappers.generate_covariates(curr_map='50', \
                                        src_polydata=sphere_mesh, \
                                        trg_polydata=sphere_mesh, \
                                        nspins=3000, datasource='grf')
# Out:
# /home/yzhou/anaconda3/envs/py311/lib/python3.11/site-packages/neuromaps/datasets/utils.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# 0.680095899862587

# %%
import pyvista as pv
import copy

pl = pv.Plotter(shape = (1,5), window_size = (1000, 200))

for i in range(Yk0.shape[0]):
    pl.subplot(0,i)
    tmp_mesh = copy.deepcopy(sphere_mesh)
    pl.add_mesh(tmp_mesh, scalars = Yk0[i, :], cmap = gnrd, **mesh_aes)
    pl.camera_position = 'yz'

pl.show(jupyter_backend = 'static')
pl.save_graphic(projdir + '/figs/main/grf_covariates_example.svg')
# Out:
# <PIL.Image.Image image mode=RGB size=1000x200>

# %%
x1, x2, x3, x4, x5 = Yk0

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(5,1, figsize = (2,10))

for k in range(Yk0.shape[0]):
    axs[k].scatter(x=Yk0[k,:], y=sphere_mesh['50'], color = 'k', edgecolor = 'none', s=2, rasterized=True, alpha=0.3)

plt.tight_layout()
plt.savefig(projdir + '/figs/main/supplements_grf_covariates_scatter.svg')

# %%
from interpmodules import metrics

collect_corr_cov = np.zeros((Yk0.shape[0], len(test_ranges)))

for ri, test_range in enumerate(test_ranges):
    Yk0, yk1 = wrappers.generate_covariates(curr_map=str(test_range), src_polydata=sphere_mesh, trg_polydata=sphere_mesh, nspins=3000, datasource='grf')

    for k in range(Yk0.shape[0]):
        collect_corr_cov[k, ri] = metrics.metric(Yk0[k,:], sphere_mesh[str(test_range)], 'pearson')
# Out:
# 0.1909526515400187
# 0.680095899862587
# 0.8591265298545981
# 0.9258498375350642

# %%
import seaborn as sns

plt.figure(figsize = (5,4))
sns.heatmap(collect_corr_cov.T, cmap = gnrd, linewidth = 1, annot = collect_corr_cov.T, linecolor = 'w', vmin=0, vmax = 1, square=True)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize = (5,4))
sns.heatmap(collect_corr_cov.T, cmap = gnrd, linewidth = 2, linecolor = 'w', vmin=0, vmax = 1, square=True)
plt.savefig(projdir + '/figs/main/supplements_grf_covariates_heatmap.svg')

# %% [markdown]
# ## Variography

# %% [markdown]
# ### Supplemental: Euclidean vs Geodesic distance bins

# %%
import matplotlib.pyplot as plt
nh = 25
X = sphere_mesh.points
x = sphere_mesh['50']

# %% [markdown]
# * distance matrices

# %%
EDist = helpers.internal_distance_matrix(sphere_mesh.points, "euclidean")

import nibabel as nb
gimg = nb.load('/home/yzhou/projects/interpolate/data/atlases/fsLR/tpl-fsLR_den-4k_hemi-L_sphere.surf.gii')
v,f = gimg.darrays[0].data, gimg.darrays[1].data
GDist = helpers.internal_distance_matrix(v,f, "geodesic")

# %% [markdown]
# * binning

# %%
import pandas as pd

N = dict.fromkeys(['euclidean', 'geodesic'])

# %%
from scipy.sparse import coo_matrix
from scipy.spatial import KDTree

max_lag = np.nanmax(EDist)
tree = KDTree(X)
spdist = tree.sparse_distance_matrix(tree, max_distance=max_lag, output_type='coo_matrix')

i_idx = spdist.row
j_idx = spdist.col
dist_ij = spdist.data

var = .5 * (x[i_idx] - x[j_idx])**2

df = pd.DataFrame({
    'h': dist_ij,
    'ev': var
})

bin_edges = np.linspace(0.000001, max_lag, nh + 1)
df['bins'] = pd.cut(df['h'], bin_edges)

N['euclidean'] = df.groupby('bins')['ev'].count().values

# %%
from scipy.sparse import coo_matrix
from scipy.spatial import KDTree

max_lag = np.nanmax(GDist)
spdist = coo_matrix(GDist)

i_idx = spdist.row
j_idx = spdist.col
dist_ij = spdist.data

var = .5 * (x[i_idx] - x[j_idx])**2

df = pd.DataFrame({
    'h': dist_ij,
    'ev': var
})

bin_edges = np.linspace(0.000001, max_lag, nh + 1)
df['bins'] = pd.cut(df['h'], bin_edges)

N['geodesic'] = df.groupby('bins')['ev'].count().values

# %% [markdown]
# * plotting

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

cmap_cont = plt.cm.gist_yarg

colors = cmap_cont(np.linspace(0,1,nh))
cmap_discrete = ListedColormap(colors)

# %%
figs, axs = plt.subplots(1,2, figsize = (6,1))

bin_edges = np.linspace(0.000001, np.nanmax(EDist), nh + 1)
bincenters = [ ( bin_edges[i] + bin_edges[i + 1] ) / 2 for i in range(nh) ]
binwidth = bincenters[1] - bincenters[0]

axs[0].bar(x=bincenters, height=N["euclidean"], align = 'center', edgecolor = 'w', color = colors, width=binwidth)
axs[0].set_xlabel("Euclidean Distance (mm)")

bin_edges = np.linspace(0.000001, np.nanmax(GDist), nh + 1)
bincenters = [ ( bin_edges[i] + bin_edges[i + 1] ) / 2 for i in range(nh) ]
binwidth = bincenters[1] - bincenters[0]

axs[1].bar(x=bincenters, height=N["geodesic"], align = 'center', edgecolor = 'w', color = colors, width=binwidth)
axs[1].set_xlabel("Geodesic Distance (mm)")

plt.savefig(projdir + '/figs/main/supplements_grf_dist_bins.svg')

# %%
import copy
import pyvista as pv
from matplotlib.colors import ListedColormap
N=25
cmap_cont = plt.cm.gist_yarg

colors = cmap_cont(np.linspace(0,1,N))
cmap_discrete = ListedColormap(colors)

pl = pv.Plotter(shape = (1,2), window_size = (400,200))

#pl.add_points(sphere_mesh.points[12], color = 'r', point_size = 12,  **point_aes)
pl.subplot(0,0)
pl.add_mesh(copy.deepcopy(sphere_mesh), scalars=EDist[20], opacity=1, cmap = cmap_discrete, **mesh_aes)
pl.camera_position = 'yz'

pl.subplot(0,1)
pl.add_mesh(copy.deepcopy(sphere_mesh), scalars=GDist[20], opacity =1, cmap = cmap_discrete, **mesh_aes)

pl.camera_position = 'yz'
pl.show(jupyter_backend = 'static')
pl.save_graphic(projdir + '/figs/main/supplements_grf_edist_gdist_sphere_bins.svg')
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
cmap_discrete

# %% [markdown]
# ### Theoretical Gaussian variograms

# %% [markdown]
# range=25,50,75,100; sill=1; nugget=0

# %%
import matplotlib.pyplot as plt
from interpmodules import helpers

fig, axs = plt.subplots(1, len(test_ranges), figsize = (4,1), sharey=True, sharex=True)

for ri, r in enumerate(test_ranges):
    x = bincenters
    theoretical = [ helpers.gaussian(h=xi, r=r, c0=1, nugget=0) for xi in x ]

    axs[ri].plot(x, theoretical, color = range_colours[ri], linewidth=2)
    axs[ri].axvline(r, color = 'k', linewidth = 1, alpha = .7)
    axs[ri].set_ylim([0,1.2])

plt.tight_layout()
#plt.show()
plt.savefig(projdir + '/figs/main/grf_instances_variograms.svg')

# %% [markdown]
# ## Absolute evenness

# %% [markdown]
# ### Experimental variograms

# %%
collect_z_fulldense_expvgm = dict()
collect_z_fullsparse_expvgm = dict()

# %%
from interpmodules import helpers

nh=25
Dist = helpers.internal_distance_matrix(sphere_mesh.points, 'euclidean')
max_lag = Dist.max()
bin_edges = np.linspace(0.000001, max_lag, nh + 1)
bin_centers = [ ( bin_edges[i] + bin_edges[i + 1] ) / 2 for i in range(nh) ]

# %% [markdown]
# #### of GRF instances

# %%
from scipy.stats import zscore

for r in test_ranges:
    novariance = zscore(sphere_mesh[str(r)])
    h,ev,nbins = helpers.get_empirical_variogram_fast(x=novariance, X=sphere_mesh.points, D=Dist,\
                                                  nh=nh,h_bounds=bin_edges, method='euclidean')
    
    collect_z_fulldense_expvgm[r] = ev

# %% [markdown]
# #### of random samples

# %%
# load samples
import joblib

niters = int(dataspecs['niters'])

for r in test_ranges:
    z_fullsparse_expvgm = np.zeros((len(test_percentages), nh, niters))
    for pi,p in enumerate(test_percentages):
        kc,kv,uc,uv = joblib.load(projdir + f'/data/sampling/fsLR-4k_sphere_samp-random_pct-{p}_iters-100.pkl')[1]
        
        for n in range(niters):
            novariance = zscore(sphere_mesh[str(r)][kv[:,n].astype(int)])
            h,ev,nbins = helpers.get_empirical_variogram_fast(x=novariance, X=kc[:,:,n], D=Dist,\
                                                          nh=nh,h_bounds=bin_edges, method='euclidean')
            z_fullsparse_expvgm[pi, :,n] = ev

    collect_z_fullsparse_expvgm[r] = z_fullsparse_expvgm
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 15
#      12         novariance = zscore(sphere_mesh[str(r)][kv[:,n].astype(int)])
#      13         #h,ev,nbins = helpers.get_empirical_variogram_fast(x=novariance, X=kc[:,:,n], D=Dist,\
#      14         #                                              nh=nh,h_bounds=bin_edges, method='euclidean')
# ---> 15         h,ev,nbins = helpers.get_empirical_variogram_fast(x=novariance, X=kc[:,:,n], D=Dist,\
#      16                                                       nh=nh,h_bounds=bin_edges, method='geodesic')
#      17         z_fullsparse_expvgm[pi, :,n] = ev
#      19 collect_z_fullsparse_expvgm[r] = z_fullsparse_expvgm
#
# File ~/gitrepo/interpolate/code/../interpmodules/helpers.py:504, in get_empirical_variogram_fast(x, X, D, nh, h_bounds, method)
#     501 j_idx = spdist.col
#     502 dist_ij = spdist.data
# --> 504 var = .5 * (x[i_idx] - x[j_idx])**2
#     506 import pandas as pd
#     508 # Create dataframe
#
# IndexError: index 200 is out of bounds for axis 0 with size 200

# %%
kc
# Out:
# array([[[-6.99586105e+01,  5.47991867e+01, -4.00266037e+01, ...,
#          -1.42784996e+01,  2.95652008e+01,  2.15378151e+01],
#         [-1.62784519e+01, -8.31750336e+01,  4.20760536e+01, ...,
#           9.75489960e+01, -9.00633087e+01, -8.60451508e+01],
#         [-6.95758896e+01, -8.88611507e+00,  8.14093170e+01, ...,
#           1.67427177e+01,  3.18511963e+01,  4.61774292e+01]],
#
#        [[ 2.45460091e+01,  9.79244995e+01, -4.26288605e+01, ...,
#          -4.52753258e+01,  7.66565704e+01,  7.96314163e+01],
#         [-6.29473534e+01, -1.12703447e+01, -7.63313293e+01, ...,
#           7.76914673e+01,  9.93041897e+00,  3.37466736e+01],
#         [ 7.37232895e+01, -1.68455353e+01,  4.85418167e+01, ...,
#          -4.37513466e+01, -6.34441223e+01, -5.01996002e+01]],
#
#        [[ 4.15444031e+01,  5.30241585e+01, -5.06554756e+01, ...,
#           8.37784729e+01, -8.58540497e+01,  7.96314163e+01],
#         [-2.43093891e+01,  8.35642471e+01,  1.86784382e+01, ...,
#           4.09209404e+01,  5.43143415e+00,  3.37466698e+01],
#         [ 8.76533813e+01, -1.43337030e+01,  8.41732635e+01, ...,
#           3.61475372e+01,  5.09860916e+01,  5.01996002e+01]],
#
#        ...,
#
#        [[ 2.20918694e+01,  7.02377014e+01,  4.99999962e+01, ...,
#          -4.15444031e+01,  3.72388763e+01,  1.60677528e+01],
#         [-1.16052971e+01, -9.78827381e+00, -3.09016972e+01, ...,
#           2.43093891e+01, -9.06318474e+00,  4.73763657e+01],
#         [-9.68362808e+01,  7.05042953e+01, -8.09016953e+01, ...,
#           8.76533813e+01,  9.23640823e+01, -8.65869827e+01]],
#
#        [[ 5.84879417e+01, -9.93562469e+01, -1.20189509e-06, ...,
#          -1.11662092e+01,  6.57872534e+00, -5.06554756e+01],
#         [-2.52905293e+01,  1.13285074e+01,  6.02911110e+01, ...,
#           2.79185905e+01, -6.73358536e+01, -1.86784363e+01],
#         [ 7.70684738e+01,  0.00000000e+00, -7.97808380e+01, ...,
#           9.53722610e+01, -7.36383133e+01,  8.41732635e+01]],
#
#        [[-6.78536911e+01, -1.73752289e+01,  1.73752289e+01, ...,
#           1.86784382e+01, -1.57371321e+01,  7.63313293e+01],
#         [-4.40692520e+01,  9.59848022e+01, -9.59848022e+01, ...,
#           8.41732635e+01, -8.20412292e+01, -4.85418167e+01],
#         [-5.87688446e+01, -2.20231419e+01,  2.20231419e+01, ...,
#          -5.06554756e+01, -5.49688950e+01, -4.26288605e+01]]],
#       shape=(200, 3, 100))

# %% [markdown]
# #### Sample recovery: MAE(random - GRF)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, len(test_ranges), figsize = (10,3), sharey = True, sharex=True)

for ri, r in enumerate(test_ranges):

    axs[ri].scatter(bin_centers, collect_z_fulldense_expvgm[r], color = 'k', s=10, zorder =10, rasterized=True)

    for pi, p in enumerate(test_percentages):
        for n in range(niters):
            axs[ri].scatter(bin_centers, collect_z_fullsparse_expvgm[r][pi,:,n], color=pct_colours[pi], \
                            edgecolor = 'none', alpha = 1, s=25, rasterized=True)

from matplotlib.lines import Line2D

legend_elements = [
    Line2D([0], [0], marker="o", color="k", linewidth =0, \
           markerfacecolor="w", markersize=10, label="random sample"),
    Line2D([0], [0], marker="o", color="k", linewidth =0, \
           markerfacecolor="k", markersize=10, label="full GRF"),
]

plt.legend(handles=legend_elements, loc = 'lower right', bbox_to_anchor=(1, 1.02), frameon=False)

plt.tight_layout()
#plt.show()
plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_variograms.svg')

# %% [markdown]
# * calculate MAE

# %%
collect_mae_exp = np.zeros((len(test_percentages), len(test_ranges) * niters))
mae_sampling_expanded = []

# %%
for pi, p in enumerate(test_percentages):
    mae_exp = []
    for ri, r in enumerate(test_ranges):
        for n in range(niters):
            gof = np.mean( metrics.metric( collect_z_fullsparse_expvgm[r][pi,:,n], collect_z_fulldense_expvgm[r], 'residual' ) )
            mae_exp.append( gof )
            mae_sampling_expanded.append([gof] * 6)
    collect_mae_exp[pi,:] = mae_exp

# %% [markdown]
# #### Model recovery: MAE(fitted - theoretical)

# %%
fitted = dict()
theoretical = dict()

# %%
# fit each sill-standardized experimental variogram to a gaussian variogram
from scipy.optimize import curve_fit

model = helpers.gaussian

x_long=np.array(bin_centers)
u=bin_centers
nparams = 3

for ri, r in enumerate(test_ranges):
    z_fullsparse_fitvgm = np.zeros((len(test_percentages), nh, niters))
    
    for pi, p in enumerate(test_percentages):
        for n in range(niters):
            
            ev=collect_z_fullsparse_expvgm[r][pi,:,n]
        
            bounds = ([0.00001]*nparams, [np.nanmax(u), np.nanmax(ev), np.nanmax(ev)/nh])
        
            cof, cov = curve_fit(model, u, ev, method = 'trf', p0=bounds[1], bounds = bounds, maxfev=1000)
            v_pred = model(x_long, *cof)
            z_fullsparse_fitvgm[pi, :, n] = v_pred
    
    fitted[r] = z_fullsparse_fitvgm

# %%
for ri, r in enumerate(test_ranges):
    theoretical[r] = np.array( [ helpers.gaussian(xi, r, 1, 0) for xi in x_long ] )

# %%
fig, axs = plt.subplots(1, len(test_ranges), figsize = (10,3), sharey = True, sharex=True)

for ri, r in enumerate(test_ranges):
    for pi, p in enumerate(test_percentages):
        
        for n in range(niters):
            axs[ri].plot(x_long, fitted[r][pi, :, n], color = range_colours[ri], alpha = .5, rasterized=True)
    
    axs[ri].plot(x_long, theoretical[r], linewidth =2, color = 'k', rasterized=True)

legend_elements = [
    Line2D([0], [0], marker="none", color="k", linewidth =1, \
           c="blue", markersize=0, label="Gaussian variogram"),
    Line2D([0], [0], marker="none", color="k", linewidth =1, \
           c="k", markersize=0, label="fitted variogram"),
]

plt.legend(handles=legend_elements, loc = 'lower right', bbox_to_anchor=(1, 1.02), frameon=False)

plt.tight_layout()

plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_fitted-variograms.svg')

# %% [markdown]
# * calculate MAE

# %%
collect_mae_fit = np.zeros((len(test_ranges), len(test_percentages) * niters))
mae_modeling_expanded = []

# %%
for ri, r in enumerate(test_ranges):
    mae_fit = []
    for pi, p in enumerate(test_percentages):
        for n in range(niters):

            gof = np.mean( metrics.metric( fitted[r][pi,:,n], theoretical[r], 'residual' ) )
            mae_fit.append( gof )
            mae_modeling_expanded.append([gof] * 6)

    collect_mae_fit[ri,:] = mae_fit

# %% [markdown]
# * Plotting MAE sampling vs modeling

# %%
fig, axs = plt.subplots(1,2, figsize = (7,2), sharex=True, sharey=True)

    
bp = axs[0].boxplot(collect_mae_exp.T, widths = 0.6, patch_artist=True, \
            flierprops = {"markerfacecolor": 'k', "mec": 'none', "markersize": 2})

for box, pi in zip(bp["boxes"], range(len(test_percentages))):
    box.set_facecolor(pct_colours[pi])
    box.set_edgecolor("black")

for median in bp["medians"]:
    median.set_color("black")
    median.set_linewidth(1)

axs[0].set_ylabel("MAE")

bp = axs[1].boxplot(collect_mae_fit.T, widths = 0.6, patch_artist=True, \
            flierprops = {"markerfacecolor": 'k', "mec": 'none', "markersize": 2})

for box, ri in zip(bp["boxes"], range(len(test_ranges))):
    box.set_facecolor(range_colours[ri])
    box.set_edgecolor("black")

for median in bp["medians"]:
    median.set_color("black")
    median.set_linewidth(1)
    
plt.tight_layout()
plt.savefig(projdir + '/figs/main/grf_mae_sill-normalized_boxplots_pct-range_stabilities.svg')

# %% [markdown]
# ## Sampling regime (VSE)

# %%
all_standardized_voronoi_se = []
all_voronoi_se = []

voronoi_se = np.zeros((niters, len(test_percentages)))
voronoi_se_zscored = np.zeros((niters, len(test_percentages)))

# %%
import joblib

for pi, p in enumerate(test_percentages):
    labels, results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_50_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
    
    for i in range(niters): voronoi_se[i, pi] = results[0][i][2]

    voronoi_se_zscored[:,pi] = zscore( voronoi_se[:,pi] )

    all_standardized_voronoi_se.append(voronoi_se_zscored)
    all_voronoi_se.append(voronoi_se)

# %%
import matplotlib.pyplot as plt
from scipy.stats import zscore, gaussian_kde

plt.figure(figsize = (6,1))
bins = np.histogram_bin_edges(voronoi_se.T, bins=25)

for pi, p in enumerate(test_percentages):

    data = voronoi_se[:,pi]
    #plt.hist(data, bins = bins, color = pct_colours[pi], edgecolor = 'w', density=True, alpha = 1)
    #plt.axvline(np.mean(voronoi_se[:,pi]), linewidth = 1, color = 'k', alpha = .5)
    x = np.linspace(data.min(), data.max(), 50)
    kde = gaussian_kde(data)
    plt.plot(x, kde(x), color = 'k', linewidth=1)

    x = np.linspace(data.min(), data.max(), 50)
    y = gaussian_kde(data)(x)
    
    plt.fill_between(x, y, 0, color = pct_colours[pi], alpha=1)

from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=pct_colours[pi], label=str(p) + "%")
    for pi, p in enumerate(test_percentages)
]

plt.legend(handles=legend_elements, title=" ", loc='lower right',
bbox_to_anchor=(1, 1.02), frameon=False, ncol = len(test_percentages))
plt.show()
#plt.savefig(projdir + '/figs/main/grf_random_sampling_voronoi.svg')

# %%
for pi in range(len(test_percentages)):
    print("Sparse sample at: " + str(test_percentages[pi]) + "%")
    print('             mean VSE: ' + str(voronoi_se[:,pi].mean()) )
    print('             variance VSE: ' + str(voronoi_se[:,pi].std()) )
# Out:
# Sparse sample at: 5%
#              mean VSE: 15.783256701562804
#              variance VSE: 0.48241018293605853
# Sparse sample at: 10%
#              mean VSE: 10.999516401186577
#              variance VSE: 0.2413647999838367
# Sparse sample at: 25%
#              mean VSE: 6.629554196190411
#              variance VSE: 0.10227638511726667
# Sparse sample at: 50%
#              mean VSE: 4.172370885216229
#              variance VSE: 0.046693473895373955

# %% [markdown]
# ## Performance

# %%
concat_everything = pd.DataFrame()

# %%
import pandas as pd

for ri, r in enumerate(test_ranges):

    concat_pct = pd.DataFrame() # rank scores by percentage
    
    for pi, p in enumerate(test_percentages):
        # load results
        labels, results = joblib.load(projdir + \
                        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        # join results for all 100 iterations
        concat_iters = pd.concat( [ results[4][i][1] for i in range(niters) ], axis = 1)
        concat_pct = pd.concat( [concat_pct, concat_iters], axis = 1)
    concat_everything = pd.concat( [concat_everything, concat_pct ], axis = 1)

# %%
aorder = concat_everything.T.mean().sort_values(ascending=False).index
print("average ranks: ")
print(aorder)
# Out:
# average ranks:
# Index(['krige', 'regkrige', 'idw', 'knn', 'swr', 'rbf'], dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (3,4))

sns.violinplot(concat_everything.T, order = aorder, orient = 'h', inner = 'box', palette=apal,\
               fill=False, inner_kws=dict(box_width=5, whis_width=5))
plt.xlabel("rank score")

plt.tight_layout()
plt.show()
#plt.savefig(projdir + '/figs/main/grf_random_samples_collapsed_rank_scores.svg')

# %% [markdown]
# ### 2D heatmap

# %%
all_rank_scores = []
long_ranges = []
long_percentages = []

# %%
import seaborn as sns
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

fig, axs = plt.subplots(1, len(test_percentages),figsize = (10, 10), sharey=True)
    
for pi, p in enumerate(test_percentages):

    gridplotdata = pd.DataFrame()
    for ri, r in enumerate(test_ranges):
        labels, results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        concat_rank_scores = pd.concat( [results[4][i][1] for i in range(niters)] , axis = 1 )

        gridplotdata[r] = concat_rank_scores.mean(axis = 1)
    gridplotdata = gridplotdata.reindex(approaches)

    sns.heatmap(gridplotdata, square = True, \
                cmap = gnrd, vmin = 0, vmax = 1, linecolor = "w", linewidth = 1, cbar = False, ax=axs[pi])
    axs[pi].set_title(f"{p}%")
    axs[pi].set_xlabel("range")

axins = inset_axes(
    axs[-1],
    width="5%",  # width: 5% of parent_bbox width
    height="50%",  # height: 50%
    loc="lower left",
    bbox_to_anchor=(1.50, 0, 1, 1),
    bbox_transform=axs[-1].transAxes,
    borderpad=0,
)
norm = mcolors.Normalize(vmin=0, vmax=1)
fig.colorbar(cm.ScalarMappable(norm=norm, cmap=gnrd), cax=axins)

plt.show()
#fig.subplots_adjust(right=1.0, bottom = 0.2)
#plt.savefig(projdir + "/figs/main/grf_random_samples_mean_rank_scores_heatmap.svg")

# %% [markdown]
# ### 3D heatmap: random samples

# %%
import joblib
import seaborn as sns
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


approaches_3d = dict.fromkeys(approaches)
fig, axs = plt.subplots(2,3, subplot_kw={"projection": "3d"}, constrained_layout=True, figsize = (8, 6))

for pi, p in enumerate(test_percentages):

    gridplotdata = pd.DataFrame()
    for ri, r in enumerate(test_ranges):

        strategy = 'random'
        
        labels, results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        concat_rank_scores = pd.concat( [results[4][i][1] for i in range(niters)] , axis = 1 )

        #strategy = 'fibonacci'
        #results = joblib.load(projdir + \
        #f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}_0_all_info.pkl')
        #concat_rank_scores = results['performance'][1]
        
        all_rank_scores.append(concat_rank_scores)
        long_ranges.append([r] * 600)
        long_percentages.append([p] * 600)
        gridplotdata[str(r)] = concat_rank_scores.mean(axis=1)
    
    gridplotdata = gridplotdata.reindex(approaches)
    
    for approach in approaches:
        if approaches_3d[approach] == None: approaches_3d[approach] = []
        approaches_3d[approach].append(gridplotdata.loc[approach])

# Make data.
X = test_ranges
Y = test_percentages
X, Y = np.meshgrid(X, Y)

for ai, approach in enumerate(aorder):

    row, col = ai // 3, ai % 3
    
    Z = pd.DataFrame(approaches_3d[approach]).to_numpy()
    
    # Plot the surface.
    surf = axs[row,col].plot_surface(X, Y, Z, vmin = 0, vmax = 1, cmap=gnrd,
                           linewidth=.3, edgecolor = 'dimgray', antialiased=False)
    axs[row,col].grid(False)
    axs[row,col].set_facecolor('none')
    axs[row,col].zaxis.set_major_formatter('{x:.02f}')
    axs[row,col].set_zlim([0,1])
    axs[row,col].set_zlabel('rank score')
    axs[row,col].set_ylabel('%')
    axs[row,col].set_xlabel('range')
    axs[row,col].set_title(approach)
    axs[row,col].view_init(45, -45)


axins = inset_axes(
    axs[-1, -1],
    width="5%",  # width: 5% of parent_bbox width
    height="50%",  # height: 50%
    loc="lower left",
    bbox_to_anchor=(1.50, 1.0, 1, 1),
    bbox_transform=axs[-1, -1].transAxes,
    borderpad=0,
)
norm = mcolors.Normalize(vmin=0, vmax=1)
fig.colorbar(cm.ScalarMappable(norm=norm, cmap=gnrd), cax=axins)


fig.set_constrained_layout_pads(
    w_pad=0.1,
    h_pad=0.1,
    hspace=0.1,
    wspace=0.1
)
fig.set_size_inches(25, 8)

plt.show()

#plt.savefig(projdir + "/figs/main/grf_fibonacci_samples_mean_rank_scores_3d_heatmap.svg")

# %% [markdown]
# ### 3D heatmap: extended Fibonacci samples

# %%
import joblib
import seaborn as sns
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

approaches_3d = dict.fromkeys(approaches)
fig, axs = plt.subplots(2,3, subplot_kw={"projection": "3d"}, constrained_layout=True, figsize = (8, 6))

for pi, p in enumerate(np.arange(5, 55, 5)):

    gridplotdata = pd.DataFrame()
    for ri, r in enumerate(np.arange(25,105,5)):

        #strategy = 'random'
        
        #labels, results = joblib.load(projdir + \
        #f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        #concat_rank_scores = pd.concat( [results[4][i][1] for i in range(niters)] , axis = 1 )

        strategy = 'fibonacci'
        results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}_0_all_info.pkl')
        concat_rank_scores = results['performance'][1]
        
        gridplotdata[r] = concat_rank_scores
    
    gridplotdata = gridplotdata.reindex(approaches)
    
    for approach in approaches:
        if approaches_3d[approach] == None: approaches_3d[approach] = []
        approaches_3d[approach].append(gridplotdata.loc[approach])

# Make data.
X = np.arange(25,105,5)
Y = np.arange(5,55,5)
X, Y = np.meshgrid(X, Y)

for ai, approach in enumerate(aorder):

    row, col = ai // 3, ai % 3
    
    Z = pd.DataFrame(approaches_3d[approach]).to_numpy()
    
    # Plot the surface.
    surf = axs[row,col].plot_surface(X, Y, Z, vmin = 0, vmax = 1, cmap=gnrd,
                           linewidth=.3, edgecolor = 'dimgray', antialiased=False)
    axs[row,col].grid(False)
    axs[row,col].set_facecolor('none')
    axs[row,col].zaxis.set_major_formatter('{x:.02f}')
    axs[row,col].set_zlim([0,1])
    axs[row,col].set_zlabel('rank score')
    axs[row,col].set_ylabel('%')
    axs[row,col].set_xlabel('range')
    axs[row,col].set_title(approach)
    axs[row,col].view_init(45, -45)


axins = inset_axes(
    axs[-1, -1],
    width="5%",  # width: 5% of parent_bbox width
    height="50%",  # height: 50%
    loc="lower left",
    bbox_to_anchor=(1.50, 1.0, 1, 1),
    bbox_transform=axs[-1, -1].transAxes,
    borderpad=0,
)
norm = mcolors.Normalize(vmin=0, vmax=1)
fig.colorbar(cm.ScalarMappable(norm=norm, cmap=gnrd), cax=axins)

#plt.tight_layout()
#fig.subplots_adjust(
#    left=0.95,
#    right=1.50,
#    bottom=0.95,
#    top=1.50,
#     wspace=0.95
#)
#fig.subplots_adjust(right=1.0, bottom = 0.2)
#plt.show()

fig.set_constrained_layout_pads(
    w_pad=0.1,
    h_pad=0.1,
    hspace=0.1,
    wspace=0.1
)
#plt.show()
fig.set_size_inches(25, 8)
#plt.savefig(projdir + "/figs/main/grf_fibonacci_samples_morecombi_mean_rank_scores_3d_heatmap.svg")

# %% [markdown]
# ## Linear regression

# %%
formulas = ( "mae_sampling ~ uneven_z * ( C(percentage) + C(range) )",\
             "mae_modeling ~ uneven_z * ( C(percentage) + C(range) )" ,\
             "rank ~ mae_sampling +  uneven_z * ( C(approach) + C(percentage) + C(range) )",\
             "rank ~ mae_modeling * (C(approach) + C(percentage) + C(range))")

# %% [markdown]
# ### _Data management_

# %%
ranks = pd.concat(all_rank_scores)
ranks_reshaped = pd.lreshape( ranks, {'rank': list(range(100))})

ranks_reshaped['approach'] = list(ranks.index) * 100
ranks_reshaped['percentage'] = np.array( long_percentages ).flatten()
ranks_reshaped['range'] = np.array( long_ranges ).flatten()
ranks_reshaped['mae_sampling'] = np.array( mae_sampling_expanded ).flatten()
ranks_reshaped['mae_modeling'] = np.array( mae_modeling_expanded ).flatten()

# %%
concat_long_voronoi = []
concat_vario_voro = []
for j in range(4):
    concat_vario_voro.append( np.array( [ [voronoi_se_zscored[i,j]] * 4 for i in range(100)]).flatten())
    long_voronoi = np.array( [ [voronoi_se_zscored[i,j]] * 24 for i in range(100)])
    long_voronoi = long_voronoi.flatten()
    concat_long_voronoi.append(long_voronoi)

# %%
ranks_reshaped['uneven_z'] = np.concatenate( concat_long_voronoi )

# %%
ranks_reshaped
# Out:
#           rank  approach  percentage  range  mae_sampling  mae_modeling  \
# 0     1.000000  regkrige           5     25      0.046677      0.006267
# 1     0.809524       swr           5     25      0.046677      0.006267
# 2     0.595238     krige           5     25      0.046677      0.006267
# 3     0.500000       idw           5     25      0.046677      0.006267
# 4     0.428571       knn           5     25      0.046677      0.006267
# ...        ...       ...         ...    ...           ...           ...
# 9595  0.809524       knn          50    100      0.009790      0.097442
# 9596  0.595238       rbf          50    100      0.009790      0.097442
# 9597  0.547619       idw          50    100      0.009790      0.097442
# 9598  0.380952  regkrige          50    100      0.009790      0.097442
# 9599  0.166667       swr          50    100      0.009790      0.097442
#
#       uneven_z
# 0     0.913761
# 1     0.913761
# 2     0.913761
# 3     0.913761
# 4     0.913761
# ...        ...
# 9595 -0.604931
# 9596 -0.604931
# 9597 -0.604931
# 9598 -0.604931
# 9599 -0.604931
#
# [9600 rows x 7 columns]

# %%
joblib.dump(ranks_reshaped, projdir + '/results/stats/grf_collected_stats_sheet_sill-normalized_all_runs.pkl')
# Out:
# ['/home/yzhou/gitrepo/interpolate//results/stats/grf_collected_stats_sheet_sill-normalized_all_runs.pkl']

# %%
ranks_reshape_skrk = ranks_reshaped[ranks_reshaped['approach'].isin(['krige', 'regkrige'])]
ranks_reshape_skrk
# Out:
#           rank  approach  percentage  range  mae_sampling  mae_modeling  \
# 0     1.000000  regkrige           5     25      0.046677      0.006267
# 2     0.595238     krige           5     25      0.046677      0.006267
# 6     1.000000  regkrige           5     25      0.056644      0.033178
# 8     0.690476     krige           5     25      0.056644      0.033178
# 12    1.000000  regkrige           5     25      0.063342      0.007128
# ...        ...       ...         ...    ...           ...           ...
# 9583  0.761905  regkrige          50    100      0.006718      0.092663
# 9588  1.000000     krige          50    100      0.006051      0.095594
# 9592  0.500000  regkrige          50    100      0.006051      0.095594
# 9594  1.000000     krige          50    100      0.009790      0.097442
# 9598  0.380952  regkrige          50    100      0.009790      0.097442
#
#       uneven_z
# 0     0.913761
# 2     0.913761
# 6     0.913761
# 8     0.913761
# 12    0.913761
# ...        ...
# 9583 -0.604931
# 9588 -0.604931
# 9592 -0.604931
# 9594 -0.604931
# 9598 -0.604931
#
# [3200 rows x 7 columns]

# %%
joblib.dump(ranks_reshape_skrk, projdir + '/results/stats/grf_collected_stats_sheet_sill-normalized_all_runs_skrk.pkl')
# Out:
# ['/home/yzhou/gitrepo/interpolate//results/stats/grf_collected_stats_sheet_sill-normalized_all_runs_skrk.pkl']

# %% [markdown]
# * arrange data

# %% [markdown]
# ### Data characteristics and performance ranks

# %%
import joblib
all_in = joblib.load(projdir + '/results/stats/grf_collected_stats_sheet_sill-normalized_all_runs.pkl')

# %%
all_in.head()
# Out:
#        rank  approach  percentage  range  mae_sampling  mae_modeling  uneven_z
# 0  1.000000  regkrige           5     25      0.046677      0.006267  0.913761
# 1  0.809524       swr           5     25      0.046677      0.006267  0.913761
# 2  0.595238     krige           5     25      0.046677      0.006267  0.913761
# 3  0.500000       idw           5     25      0.046677      0.006267  0.913761
# 4  0.428571       knn           5     25      0.046677      0.006267  0.913761

# %%
np.corrcoef(all_in['mae_sampling'], all_in['mae_modeling'])
# Out:
# array([[ 1.        , -0.83039458],
#        [-0.83039458,  1.        ]])

# %%
np.corrcoef(all_in['mae_modeling'], all_in['uneven_z'])
# Out:
# array([[1.        , 0.01295807],
#        [0.01295807, 1.        ]])

# %%
np.corrcoef(all_in['mae_sampling'], all_in['uneven_z'])
# Out:
# array([[1.        , 0.02525891],
#        [0.02525891, 1.        ]])

# %%
scatter_aes = {"edgecolor": 'none', "alpha":0.3, "s": 10, "rasterized":True, "legend":False}

# %%
fig, axs = plt.subplots(2,2, figsize = (7,6), sharex=True)

sns.scatterplot(all_in, y='mae_sampling', x='uneven_z', hue = 'percentage', palette= list(pct_colours), \
                **scatter_aes, ax=axs[0,0])

sns.scatterplot(all_in, y='mae_modeling', x='uneven_z', hue = 'percentage', palette= list(pct_colours), \
                **scatter_aes, ax=axs[0,1])

sns.scatterplot(all_in, y='mae_sampling', x='uneven_z', hue = 'range', palette= list(range_colours), \
                **scatter_aes, ax=axs[1,0])

sns.scatterplot(all_in, y='mae_modeling', x='uneven_z', hue = 'range', palette= list(range_colours), \
                **scatter_aes, ax=axs[1,1])

plt.tight_layout()
plt.savefig(projdir + "/figs/main/supplements_grf_mae_vse.svg")

# %%
sns.lmplot(
    data=df,
    x="uneven_z",
    y="mae_sampling",
    hue="percentage",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": 1, "s": 10, "edgecolor": "none", "rasterized":True},
    line_kws={"linewidth": 1, "color" : 'k' },
    palette = list(pct_colours),\
    legend=False,
    height = 3, aspect = 1.2
)
plt.ylim([0,0.15])
plt.tight_layout()
plt.savefig(projdir + "/figs/main/grf_mae_sampling_vse.svg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 sns.lmplot(
# ----> 2     data=df,
#       3     x="uneven_z",
#       4     y="mae_sampling",
#       5     hue="percentage",
#       6     col_wrap=None,
#       7     ci=None,
#       8     scatter_kws={"s": 20, "alpha": 1, "s": 10, "edgecolor": "none", "rasterized":True},
#       9     line_kws={"linewidth": 1, "color" : 'k' },
#      10     palette = list(pct_colours),\
#      11     legend=False,
#      12     height = 3, aspect = 1.2
#      13 )
#      14 plt.ylim([0,0.15])
#      15 plt.tight_layout()
#
# NameError: name 'df' is not defined

# %%
sns.lmplot(
    data=df,
    x="uneven_z",
    y="mae_modeling",
    hue="percentage",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": 1, "s": 10, "edgecolor": "none", "rasterized":True},
    line_kws={"linewidth": 1, "color" : 'k' },
    palette = list(pct_colours),\
    legend=False,
    height = 3, aspect = 1.2
)
plt.ylim([0,0.15])
plt.tight_layout()
plt.savefig(projdir + "/figs/main/grf_mae_modeling_vse.svg")

# %% [markdown]
# * The OLS

# %%
import statsmodels.formula.api as smf

df = all_in

df["percentage"] = df["percentage"].astype("category")
df["range"] = df["range"].astype("category")
df["approach"] = df["approach"].astype("category")

# %%
mdl0 = smf.ols(formulas[0], data=df).fit(cov_type="HC3")
mdl1 = smf.ols(formulas[1], data=df).fit(cov_type="HC3")
mdl2 = smf.ols(formulas[2], data=df).fit(cov_type="HC3")

# %%
mdl1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           mae_modeling   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 1.643e+04
# Date:                Mon, 02 Mar 2026   Prob (F-statistic):               0.00
# Time:                        16:14:59   Log-Likelihood:                 31639.
# No. Observations:                9600   AIC:                        -6.325e+04
# Df Residuals:                    9586   BIC:                        -6.315e+04
# Df Model:                          13
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0164      0.000     61.972      0.000       0.016       0.017
# C(percentage)[T.10]              0.0253      0.000    136.250      0.000       0.025       0.026
# C(percentage)[T.25]              0.0764      0.000    276.957      0.000       0.076       0.077
# C(percentage)[T.50]              0.0823      0.000    360.572      0.000       0.082       0.083
# C(range)[T.50]                  -0.0021      0.000     -6.123      0.000      -0.003      -0.001
# C(range)[T.75]                  -0.0035      0.000    -11.835      0.000      -0.004      -0.003
# C(range)[T.100]                 -0.0037      0.000    -13.140      0.000      -0.004      -0.003
# uneven_z                         0.0013      0.000      5.238      0.000       0.001       0.002
# uneven_z:C(percentage)[T.10] -7.246e-05      0.000     -0.402      0.688      -0.000       0.000
# uneven_z:C(percentage)[T.25]    -0.0004      0.000     -1.498      0.134      -0.001       0.000
# uneven_z:C(percentage)[T.50]     0.0002      0.000      1.041      0.298      -0.000       0.001
# uneven_z:C(range)[T.50]         -0.0008      0.000     -2.464      0.014      -0.001      -0.000
# uneven_z:C(range)[T.75]         -0.0011      0.000     -3.947      0.000      -0.002      -0.001
# uneven_z:C(range)[T.100]        -0.0013      0.000     -4.681      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                      933.361   Durbin-Watson:                   0.339
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5950.949
# Skew:                          -0.230   Prob(JB):                         0.00
# Kurtosis:                       6.830   Cond. No.                         5.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
mdl0.pvalues
# Out:
# Intercept                       0.000000e+00
# C(percentage)[T.10]             0.000000e+00
# C(percentage)[T.25]             0.000000e+00
# C(percentage)[T.50]             0.000000e+00
# C(range)[T.50]                  8.291019e-08
# C(range)[T.75]                  2.554335e-03
# C(range)[T.100]                 6.398059e-09
# uneven_z                        2.839435e-04
# uneven_z:C(percentage)[T.10]    1.200867e-03
# uneven_z:C(percentage)[T.25]    6.728691e-05
# uneven_z:C(percentage)[T.50]    5.829235e-04
# uneven_z:C(range)[T.50]         9.910020e-01
# uneven_z:C(range)[T.75]         3.047353e-01
# uneven_z:C(range)[T.100]        4.186594e-02
# dtype: float64

# %%
from statsmodels.stats.multitest import multipletests

# Assuming model.pvalues is a list or array of p-values from your OLS model
p_values = mdl0.pvalues

# Apply Bonferroni correction
reject, corrected_pvalues, _, _ = multipletests(p_values, method='bonferroni')

# %%
corrected_pvalues
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.16074261e-06, 3.57606901e-02, 8.95728275e-08, 3.97520848e-03,
#        1.68121380e-02, 9.42016790e-04, 8.16092860e-03, 1.00000000e+00,
#        1.00000000e+00, 5.86123090e-01])

# %%
fig, axs = plt.subplots(3,1, figsize = (3, 11), sharey=True)

sns.scatterplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="approach",
    alpha=0.2,
    edgecolor = 'none',
    palette=apal,
    legend=False,
    rasterized=True,
    ax=axs[0]
)

sns.scatterplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    alpha=0.2,
    edgecolor = 'none',
    palette = apal,
    legend=False,
    rasterized=True,
    ax=axs[1]
)

sns.scatterplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",
    alpha=0.2,
    edgecolor = 'none',
    palette = apal,
    legend=False,
    rasterized=True,
    ax=axs[2]
)
plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_ols_unevenness_ranks_main.svg')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))

sns.lmplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    col_wrap=None,
    ci=None,
    scatter=False,
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)
plt.ylim([0,1])
plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-maesamp_full2_noscatter.svg')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))

sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",
    col_wrap=None,
    ci=None,
    scatter=False,
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)
plt.ylim([0,1])
plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_full2_noscatter.svg')

# %%
g = sns.lmplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    ci=None,
    scatter=False,
    palette=apal, legend = False,
    line_kws={'linewidth':3}, height = 3, aspect=1
)

ax = g.ax

sns.scatterplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="range",
    palette=range_colours,
    ax=ax,
    s=20, alpha=0.5, edgecolor = 'none',
    legend=False
)

#plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_ols_unevenness_performance_ranges_w_slope.svg')
# Out:
# /tmp/ipykernel_2668981/2627033091.py:14: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.scatterplot(
# <Axes: xlabel='mae_sampling', ylabel='rank'>

# %%
g = sns.lmplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    ci=None,
    scatter=False,
    palette=apal, legend = False,
    line_kws={'linewidth':3}, height = 3, aspect=1
)

ax = g.ax

sns.scatterplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="percentage",
    palette=pct_colours,
    ax=ax,
    s=20, alpha=0.5, edgecolor = 'none',
    legend=False
)

#plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_ols_unevenness_performance_ranges_w_slope.svg')
# Out:
# /tmp/ipykernel_2668981/1532052134.py:14: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.scatterplot(
# <Axes: xlabel='mae_sampling', ylabel='rank'>

# %%
g = sns.lmplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="approach",
    col_wrap=None,
    ci=None,
    scatter=False,
    palette=apal, legend = False,
    line_kws={'linewidth':3}, height = 3, aspect=1
)

ax = g.ax

sns.scatterplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="percentage",
    palette=pct_colours,
    ax=ax,
    s=20, alpha=0.3, edgecolor = 'none',
    legend=False
)

#plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_ols_unevenness_performance_percentages_w_slope.svg')
# Out:
# /tmp/ipykernel_2668981/1057265088.py:15: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.scatterplot(
# <Axes: xlabel='uneven_z', ylabel='rank'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))

sns.lmplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="approach",
    col_wrap=None,
    ci=None,
    scatter=False,
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)

#plt.show()
plt.ylim([0,1])
plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_full1_noscatter.svg')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))
g = sns.lmplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="approach",
    col="percentage",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": 0.1, "edgecolor": "none"},
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)

from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=to_rgba(acolours[ai]), label=approach)
    for ai, approach in enumerate(approaches)
]

plt.legend(handles=legend_elements, \
           loc='lower right', \
           frameon=False, \
           ncol = 1,\
            bbox_to_anchor=(1.75, 0.25),  # outside right
            borderaxespad=0.5)

g.set_axis_labels("unevenness", "accuracy rank")
g.set_titles("{col_name}%")

plt.tight_layout()
#plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_percent-vse.png', dpi=300)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))
g = sns.lmplot(
    data=df,
    x="uneven_z",
    y="rank",
    hue="approach",
    col="range",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": .1, "edgecolor": "none"},
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)

from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=to_rgba(acolours[ai]), label=approach)
    for ai, approach in enumerate(approaches)
]

plt.legend(handles=legend_elements, \
           loc='lower right', \
           frameon=False, \
           ncol = 1,\
            bbox_to_anchor=(1.75, 0.25),  # outside right
            borderaxespad=0.5)

g.set_axis_labels("unevenness", "accuracy rank")
g.set_titles("range={col_name}")

plt.tight_layout()
#plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_range-vse.png', dpi=300)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))
g = sns.lmplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    col="percentage",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": .1, "edgecolor": "none"},
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)

from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=to_rgba(acolours[ai]), label=approach)
    for ai, approach in enumerate(approaches)
]

plt.legend(handles=legend_elements, \
           loc='lower right', \
           frameon=False, \
           ncol = 1,\
            bbox_to_anchor=(1.75, 0.25),  # outside right
            borderaxespad=0.5)

g.set_axis_labels("mae_sampling", "accuracy rank")
g.set_titles("{col_name}%")

plt.tight_layout()
#plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_percent-mae.png', dpi=300)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize = (5,5))
g = sns.lmplot(
    data=df,
    x="mae_sampling",
    y="rank",
    hue="approach",
    col="range",
    col_wrap=None,
    ci=None,
    scatter_kws={"s": 20, "alpha": .1, "edgecolor": "none"},
    line_kws={"linewidth": 3},
    palette = apal,\
    legend=False,
    height = 3, aspect = 1
)

from matplotlib.patches import Patch

legend_elements = [
    Patch(facecolor=to_rgba(acolours[ai]), label=approach)
    for ai, approach in enumerate(approaches)
]

plt.legend(handles=legend_elements, \
           loc='lower right', \
           frameon=False, \
           ncol = 1,\
            bbox_to_anchor=(1.75, 0.25),  # outside right
            borderaxespad=0.5)

g.set_axis_labels("mae_sampling", "accuracy rank")
g.set_titles("range={col_name}")

plt.tight_layout()
#plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_sill-normalized_ols_rank-vse-mae_range-mae.png', dpi = 300)

# %% [markdown]
# ### Model recovery and kriging/regression kriging ranks

# %%
kr_in = joblib.load(projdir + '/results/stats/grf_collected_stats_sheet_sill-normalized_all_runs_skrk.pkl')

# %%
kr_in
# Out:
#           rank  approach  percentage  range  mae_sampling  mae_modeling  \
# 0     1.000000  regkrige           5     25      0.046677      0.006267
# 2     0.595238     krige           5     25      0.046677      0.006267
# 6     1.000000  regkrige           5     25      0.056644      0.033178
# 8     0.690476     krige           5     25      0.056644      0.033178
# 12    1.000000  regkrige           5     25      0.063342      0.007128
# ...        ...       ...         ...    ...           ...           ...
# 9583  0.761905  regkrige          50    100      0.006718      0.092663
# 9588  1.000000     krige          50    100      0.006051      0.095594
# 9592  0.500000  regkrige          50    100      0.006051      0.095594
# 9594  1.000000     krige          50    100      0.009790      0.097442
# 9598  0.380952  regkrige          50    100      0.009790      0.097442
#
#       uneven_z
# 0     0.913761
# 2     0.913761
# 6     0.913761
# 8     0.913761
# 12    0.913761
# ...        ...
# 9583 -0.604931
# 9588 -0.604931
# 9592 -0.604931
# 9594 -0.604931
# 9598 -0.604931
#
# [3200 rows x 7 columns]

# %%
import statsmodels.formula.api as smf
df = kr_in

df["approach"] = df["approach"].astype("category")
df["percentage"] = df["percentage"].astype("category")
df["range"] = df["range"].astype("category")

# %%
df
# Out:
#           rank  approach percentage range  mae_sampling  mae_modeling  \
# 0     1.000000  regkrige          5    25      0.046677      0.006267
# 2     0.595238     krige          5    25      0.046677      0.006267
# 6     1.000000  regkrige          5    25      0.056644      0.033178
# 8     0.690476     krige          5    25      0.056644      0.033178
# 12    1.000000  regkrige          5    25      0.063342      0.007128
# ...        ...       ...        ...   ...           ...           ...
# 9583  0.761905  regkrige         50   100      0.006718      0.092663
# 9588  1.000000     krige         50   100      0.006051      0.095594
# 9592  0.500000  regkrige         50   100      0.006051      0.095594
# 9594  1.000000     krige         50   100      0.009790      0.097442
# 9598  0.380952  regkrige         50   100      0.009790      0.097442
#
#       uneven_z
# 0     0.913761
# 2     0.913761
# 6     0.913761
# 8     0.913761
# 12    0.913761
# ...        ...
# 9583 -0.604931
# 9588 -0.604931
# 9592 -0.604931
# 9594 -0.604931
# 9598 -0.604931
#
# [3200 rows x 7 columns]

# %%
mdl3 = smf.ols("rank ~ mae_modeling * (C(approach) + C(percentage) + C(range))", data=df).fit(cov_type="HC3")

print(mdl3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rank   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5884
# Date:                Mon, 02 Mar 2026   Prob (F-statistic):              0.886
# Time:                        15:47:46   Log-Likelihood:                 1280.5
# No. Observations:                3200   AIC:                            -2529.
# Df Residuals:                    3184   BIC:                            -2432.
# Df Model:                          15
# Covariance Type:                  HC3
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.8592      0.020     42.698      0.000       0.820       0.899
# C(approach)[T.regkrige]                 -0.0126      0.011     -1.121      0.262      -0.035       0.009
# C(percentage)[T.10]                     -0.0056      0.033     -0.167      0.867      -0.071       0.060
# C(percentage)[T.25]                     -0.0240      0.051     -0.474      0.635      -0.123       0.075
# C(percentage)[T.50]                     -0.0377      0.061     -0.613      0.540      -0.158       0.083
# C(range)[T.50]                           0.0059      0.016      0.366      0.715      -0.026       0.038
# C(range)[T.75]                           0.0044      0.016      0.271      0.787      -0.028       0.037
# C(range)[T.100]                         -0.0004      0.017     -0.022      0.982      -0.033       0.033
# mae_modeling                             0.2039      0.987      0.207      0.836      -1.730       2.138
# mae_modeling:C(approach)[T.regkrige]    -0.0496      0.160     -0.310      0.756      -0.363       0.264
# mae_modeling:C(percentage)[T.10]         0.0378      1.199      0.031      0.975      -2.313       2.388
# mae_modeling:C(percentage)[T.25]         0.1475      1.095      0.135      0.893      -1.999       2.294
# mae_modeling:C(percentage)[T.50]         0.2504      1.140      0.220      0.826      -1.984       2.485
# mae_modeling:C(range)[T.50]             -0.0259      0.225     -0.115      0.908      -0.467       0.415
# mae_modeling:C(range)[T.75]             -0.0437      0.230     -0.190      0.849      -0.494       0.407
# mae_modeling:C(range)[T.100]            -0.0242      0.237     -0.102      0.918      -0.488       0.440
# ==============================================================================
# Omnibus:                      447.649   Durbin-Watson:                   3.327
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              653.868
# Skew:                          -1.090   Prob(JB):                    1.03e-142
# Kurtosis:                       3.389   Cond. No.                         944.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
import seaborn as sns

g=sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",        # krige vs regkrige
    ci=None,
    scatter=False,
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.5},
    aspect = 1, height = 3
)

ax=g.ax

sns.scatterplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="range",
    palette=range_colours,
    ax=ax,
    s=20, alpha=.5, edgecolor = 'none',
    legend=False
)


#plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_slopes_by_range.svg')
# Out:
# /tmp/ipykernel_2668981/3825763269.py:18: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.scatterplot(
# <Axes: xlabel='mae_modeling', ylabel='rank'>

# %%
import seaborn as sns

g=sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",        # krige vs regkrige
    ci=None,
    scatter_kws={"s": 20, "alpha": 0.1, "edgecolor": "none"},
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.5},
    aspect = 1, height = 3
)

plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_slopes_by_approach.svg')

# %%
import seaborn as sns

g=sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",        # krige vs regkrige
    ci=None,
    scatter=False,
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.5},
    aspect = 2, height = 2.5
)
plt.ylim([.8, 1])
plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_slopes_by_approach_noscatter.svg')

# %%
import seaborn as sns

g=sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",        # krige vs regkrige
    ci=None,
    scatter=False,
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.5},
    aspect = 1, height = 3
)

ax=g.ax

sns.scatterplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="percentage",
    palette=pct_colours,
    ax=ax,
    s=20, alpha=.5, edgecolor = 'none',
    legend=False
)


plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_slopes_by_percentage.svg')
# Out:
# /tmp/ipykernel_2668981/3249980992.py:18: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.scatterplot(

# %%
sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",
    col="percentage",      # or col="range"
    col_wrap=len(test_percentages),
    ci=None,
    scatter_kws={
        "alpha": 0.3,
        "s": 20,
        "edgecolor": "none"
    },
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.2},
    aspect = .9, height = 3
)

plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_by_percentage.svg')

# %%
sns.lmplot(
    data=df,
    x="mae_modeling",
    y="rank",
    hue="approach",
    col="range",      # or col="range"
    col_wrap=len(test_ranges),
    ci=None,
    scatter_kws={
        "alpha": 0.3,
        "s": 20,
        "edgecolor": "none"
    },
    palette=apal,
    legend=False,
    line_kws={"linewidth": 2.2},
    aspect = .9, height = 3
)

plt.savefig(projdir + '/figs/main/grf_random_samples_sill-normalized_kriging_rank_vs_mae_by_range.svg')

# %%
bad = df["mae_modeling"].quantile(0.9)      # define "bad fit" as top 10% MAE
df["mae_bad"] = df["mae_modeling"] - bad

m_bad = smf.ols(
    "rank ~ mae_bad * ( C(approach) + C(percentage) + C(range) )",
    data=df
).fit(cov_type="HC3")
print(m_bad.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rank   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5884
# Date:                Thu, 26 Feb 2026   Prob (F-statistic):              0.886
# Time:                        15:09:03   Log-Likelihood:                 1280.5
# No. Observations:                3200   AIC:                            -2529.
# Df Residuals:                    3184   BIC:                            -2432.
# Df Model:                          15
# Covariance Type:                  HC3
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           0.8798      0.083     10.555      0.000       0.716       1.043
# C(approach)[T.regkrige]            -0.0177      0.009     -2.039      0.041      -0.035      -0.001
# C(percentage)[T.10]                -0.0017      0.094     -0.018      0.985      -0.186       0.183
# C(percentage)[T.25]                -0.0091      0.083     -0.109      0.913      -0.173       0.154
# C(percentage)[T.50]                -0.0124      0.083     -0.149      0.882      -0.176       0.151
# C(range)[T.50]                      0.0033      0.012      0.274      0.784      -0.020       0.027
# C(range)[T.75]                    2.01e-05      0.012      0.002      0.999      -0.024       0.024
# C(range)[T.100]                    -0.0028      0.013     -0.223      0.824      -0.028       0.022
# mae_bad                             0.2039      0.987      0.207      0.836      -1.730       2.138
# mae_bad:C(approach)[T.regkrige]    -0.0496      0.160     -0.310      0.756      -0.363       0.264
# mae_bad:C(percentage)[T.10]         0.0378      1.199      0.031      0.975      -2.313       2.388
# mae_bad:C(percentage)[T.25]         0.1475      1.095      0.135      0.893      -1.999       2.294
# mae_bad:C(percentage)[T.50]         0.2504      1.140      0.220      0.826      -1.984       2.485
# mae_bad:C(range)[T.50]             -0.0259      0.225     -0.115      0.908      -0.467       0.415
# mae_bad:C(range)[T.75]             -0.0437      0.230     -0.190      0.849      -0.494       0.407
# mae_bad:C(range)[T.100]            -0.0242      0.237     -0.102      0.918      -0.488       0.440
# ==============================================================================
# Omnibus:                      447.649   Durbin-Watson:                   3.327
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              653.868
# Skew:                          -1.090   Prob(JB):                    1.03e-142
# Kurtosis:                       3.389   Cond. No.                         946.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
import seaborn as sns
import matplotlib.colors as mcolors
import pandas as pd

fig, axs = plt.subplots(len(test_ranges), len(test_percentages), figsize = (10, 10), sharex=True, sharey=True)
methods_order = approaches
for ri, r in enumerate(test_ranges):
    for pi, p in enumerate(test_percentages):

        strategy = 'random'
        labels, results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        concat_rank_scores = pd.concat( [results[4][i][1] for i in range(niters)] , axis = 1 )
        
        sns.boxplot(concat_rank_scores.T, orient ='h', fliersize =0, order = methods_order, linewidth=2, \
                    fill=False, color = mcolors.to_hex( pct_colours[pi] ), ax=axs[ri, pi])
        
        strategy = 'fibonacci'
        results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}_0_all_info.pkl')
        run_rank_scores = results['performance'][1]
        
        sns.pointplot(x=run_rank_scores, y=run_rank_scores.index, order = methods_order, \
                      color = 'k', linestyle = "none", ax=axs[ri, pi], zorder = 10)
        
        axs[len(test_ranges)-1, pi].set_xlabel("rank score")
        axs[ri, 0].set_ylabel(f"range={str(r)}")

from matplotlib.lines import Line2D

legend_elements = [
    Line2D([0], [0], marker="o", color="k", linewidth =0, \
           markerfacecolor="k", markersize=8, label="fibonacci"),
]

plt.legend(handles=legend_elements, loc = 'lower left', bbox_to_anchor=(1.05, 0., 1, 1), frameon=False)

plt.tight_layout()
#plt.show()
#plt.savefig(projdir + '/figs/main/grf_random_samples_and_fibonacci_rank_scores.svg')

# %%
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
fig, axs = plt.subplots(len(test_ranges), len(test_percentages), figsize = (10,10), sharex=True, sharey=True)
strategy = 'random'
for ri, r in enumerate(test_ranges):
    for pi, p in enumerate(test_percentages):
        labels, results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')
        mean_metric_scores = np.mean( [results[4][i][0].loc[metrics_to_consider[:-1]].T for i in range(niters)], axis = 0)
        
        sns.heatmap(mean_metric_scores.T, yticklabels=metrics_to_consider[:-1], xticklabels = approaches, \
                    cmap = gnrd, vmin =0, vmax = 1, cbar = False,\
                   square=True, linewidth = .5, linecolor = 'dimgray', ax=axs[ri, pi])

        axs[ri,pi].tick_params(
            axis='both',
            which='both',
            bottom=False,
            top=False,
            left=False,
            right=False,
        )
        
        axs[0, pi].set_title(f'{p}%', fontsize = 10)
        axs[ri, 0].set_ylabel(f"range={str(r)}", fontsize = 10)

axins = inset_axes(
    axs[-1,-1],
    width="5%",  # width: 5% of parent_bbox width
    height="50%",  # height: 50%
    loc="lower left",
    bbox_to_anchor=(1.05, 1.50, 1, 1),
    bbox_transform=axs[-1,-1].transAxes,
    borderpad=0,
)
norm = mcolors.Normalize(vmin=0, vmax=1)
fig.colorbar(cm.ScalarMappable(norm=norm, cmap=gnrd), cax=axins)

#plt.tight_layout()
fig.subplots_adjust(right=0.85, bottom = 0.2)
#plt.show()
plt.savefig(projdir + '/figs/main/supplements_grf_random_samples_mean_performance_metrics.svg')

# %%
import pyvista as pv

r=50
p=25

labels, results = joblib.load(projdir + \
f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}.pkl')

# %%
import copy
import pyvista as pv

pl = pv.Plotter(window_size = (400,400))

desc, sampling = joblib.load(projdir + f'/data/sampling/fsLR-4k_sphere_samp-random_pct-25_iters-100.pkl')
known_coords, known_verts , unknown_coords, unknown_verts= sampling

tmp_mesh = copy.deepcopy(sphere_mesh)
pl.add_mesh(tmp_mesh, color = 'dimgray', opacity = .7, **mesh_aes)
pl.add_points(known_coords[:,:,20], scalars = sphere_mesh['50'][known_verts[:,20].astype(int)], \
              point_size = 12, cmap = gnrd, show_scalar_bar=False, **point_aes)
pl.add_text(str(p)+"%", position = "lower_edge", font = "courier", font_size = 8)
pl.camera_position = 'yz'
pl.show(jupyter_backend='static')
pl.save_graphic(projdir + '/figs/main/supplements_grf_example_interps_subsample.svg')
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
pl = pv.Plotter(shape = (1,6), window_size = (2400,400))

for ai, approach in enumerate(approaches):
    fullmap = np.zeros(sphere_mesh.n_points)

    fullmap[ unknown_verts[:,20] ] = results[3][20][approach]
    fullmap[ known_verts[:, 20] ] = sphere_mesh[str(r)][ known_verts[:,20] ] 

    pl.subplot(0, ai)
    
    pl.add_mesh(sphere_mesh, scalars = fullmap, cmap = gnrd, **mesh_aes)
    pl.add_text(approach, position = 'lower_edge', font = 'courier', font_size = 8)
    pl.camera_position = 'yz'
pl.show(jupyter_backend='static')
pl.save_graphic(projdir + '/figs/main/supplements_grf_example_interps_maps.svg')
# Out:
# <PIL.Image.Image image mode=RGB size=2400x400>

# %%
results[4][20]
# Out:
# (                         idw       knn       rbf        swr     krige  \
#  pearson             0.972080  0.978863  0.971942   0.942207  0.996628
#  spearman            0.970041  0.977162  0.969639   0.965011  0.996207
#  ssim                0.999589  0.999501  0.999349   0.998611  0.999899
#  r2                  0.944827  0.955158  0.941043   0.886923  0.991226
#  rmse                0.242949  0.219026  0.251143   0.347808  0.096883
#  kolmogorov_smirnov  0.014657  0.028981  0.031979   0.082278  0.015989
#  jensen_shannon      0.022668  0.017827  0.022203   0.036448  0.004130
#  run_time            0.102820  0.013837  0.433693  11.594681  7.658396
#
#                       regkrige
#  pearson              0.989144
#  spearman             0.992987
#  ssim                 0.999805
#  r2                   0.978278
#  rmse                 0.152441
#  kolmogorov_smirnov   0.026316
#  jensen_shannon       0.007640
#  run_time            17.951198  ,
#  krige       0.976190
#  regkrige    0.809524
#  knn         0.619048
#  idw         0.571429
#  rbf         0.357143
#  swr         0.166667
#  dtype: float64)

# %%
plt.figure(figsize = (2,2))
mean_metric_scores = results[4][20][0].loc[metrics_to_consider[:-1]]
sns.heatmap(mean_metric_scores, yticklabels=metrics_to_consider[:-1], xticklabels = approaches, \
                    cmap = gnrd, cbar = True,\
                   square=True, linewidth = .5, linecolor = 'dimgray')
plt.savefig(projdir + '/figs/main/supplements_grf_example_interps_perfs.svg')

# %%
results[4][20][1].reindex(approaches)
# Out:
# idw         0.571429
# knn         0.619048
# rbf         0.357143
# swr         0.166667
# krige       0.976190
# regkrige    0.809524
# dtype: float64

# %%
plt.figure(figsize = (2,2))

sns.heatmap(results[4][20][1].reindex(approaches).to_numpy().reshape(1,-1), xticklabels = approaches, \
                    cmap = gnrd, cbar = True,\
                   square=True, linewidth = .5, linecolor = 'dimgray')

plt.savefig(projdir + '/figs/main/supplements_grf_example_interps_ranks.svg')

# %% [markdown]
# # Fibonacci samples

# %%
space = 'fsLR-4k'
datasource='grf'
geometry = 'sphere'
strategy = 'fibonacci'
niters = 1

# %%
import seaborn as sns
import matplotlib.colors as mcolors
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
fig, axs = plt.subplots(len(test_ranges), len(test_percentages), figsize = (10,10), sharex=True, sharey=True)

for ri, r in enumerate(test_ranges):
    for pi, p in enumerate(test_percentages):
        results = joblib.load(projdir + \
        f'/results/{datasource}/{strategy}/{space}_{str(r)}_{geometry}_{datasource}_samp-{strategy}_pct-{str(p)}_0_all_info.pkl')
        mean_metric_scores = results['performance'][0].loc[metrics_to_consider[:-1]].T
        
        sns.heatmap(mean_metric_scores, xticklabels=metrics_to_consider[:-1], yticklabels = approaches, \
                    square=True, cmap = gnrd, linewidth = .5, linecolor = 'dimgray', ax=axs[ri, pi], cbar = False)
        axs[0, pi].set_title(f'{p}%', fontsize = 10)
        axs[ri, 0].set_ylabel(f"range={str(r)}", fontsize = 10)

axins = inset_axes(
    axs[-1,-1],
    width="5%",  # width: 5% of parent_bbox width
    height="50%",  # height: 50%
    loc="lower left",
    bbox_to_anchor=(1.05, 0., 1, 1),
    bbox_transform=axs[-1,-1].transAxes,
    borderpad=0,
)
norm = mcolors.Normalize(vmin=np.min(mean_metric_scores), vmax=np.max(mean_metric_scores))
fig.colorbar(cm.ScalarMappable(norm=norm, cmap=gnrd), cax=axins)
fig.subplots_adjust(right=0.85, bottom = 0.2)
plt.show()
#plt.savefig(projdir + '/figs/main/grf_fibonacci_samples_performance_metrics.svg')
