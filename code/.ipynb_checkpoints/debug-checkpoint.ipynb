# %%
from wrappers import *
from config import *

# %%
args = {'geometry':'sphere', \
    'percentage': 2,\
    'strategy': 'random',\
    'niterations': 100, \
    'maptag': '50'}
polydata = fetch_polydata(geometry='sphere', space = 'fsLR-4k', datasource = 'grf')
desc,all_sampling = fetch_sample(**args)

# %%
print(desc)
print(polydata.array_names)
# Out:
# ('known_coords', 'known_verts', 'unknown_coords', 'unknown_verts')
# ['field', '25', '50', '75', '100']

# %%
Yk0 = generate_covariates(polydata[args['maptag']], polydata, 100, 'grf')
# Out:
# /home/yzhou/anaconda3/envs/py311/lib/python3.11/site-packages/neuromaps/datasets/utils.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# 0.2748338870523338

# %%
import sys
sys.path.append('../')
from interpmodules import deterministic

# %%
ground_truth = polydata[args['maptag']]
curr_iter=0
# unpack variables
all_known_coords, all_known_verts, all_unknown_coords, all_unknown_verts = all_sampling
known_coords = all_known_coords[:,:,curr_iter]
known_verts = all_known_verts[:,curr_iter].astype(int)
unknown_coords = all_unknown_coords[:,:,curr_iter]
unknown_verts = all_unknown_verts[:,curr_iter].astype(int)

# %%
input_vals = ground_truth[known_verts].flatten()
input_coords = known_coords

X0 = input_coords
x1 = unknown_coords
Y0 = input_vals
y0 = ground_truth[unknown_verts].flatten() # actual values



tmp = deterministic.interpolate_RBF(X0, Y0, x1, n_neighbours=10, kernel='cubic')

# %%
import copy
from interpmodules import geospatial


for curr_iter in range(2):

    unknown_verts = all_unknown_verts[:,curr_iter].astype(int)

    X0_extended = polydata.points
    Y0_extended = copy.deepcopy(ground_truth)
    Y0_extended[unknown_verts] = 0
    Yk_extended = Yk0



    geospatial.smoothing_over_GWR(X0=X0_extended, Y0=Y0_extended, Yk0=Yk_extended, bandwidth=None, timeit=True)
# Out:
# Note: not learning new coefficient, using coefficients at KNOW LOCATIONS to smooth over ZEROED UNKNOWN VALUES
# Note: not learning new coefficient, using coefficients at KNOW LOCATIONS to smooth over ZEROED UNKNOWN VALUES

# %%
from joblib import Parallel, delayed


Parallel(n_jobs=100, backend='loky')(
    delayed(deterministic.interpolate_and_optimize)(
        method='rbf',
        X0=all_known_coords[:, :, curr_iter],
        Y0=ground_truth[all_known_verts[:, curr_iter].astype(int)],
        x1=all_unknown_coords[:, :, curr_iter],
        ground_truth=ground_truth[all_unknown_verts[:, curr_iter].astype(int)].flatten(),
        bounds=[2, 20]
    )
    for curr_iter in range(100)
)
# Out:
# 16 cubic
# 11 multiquadric
# 11 multiquadric
# 5 multiquadric
# 3 multiquadric
# 9 multiquadric
# 14 cubic
# 18 cubic
# 15 cubic
# 18 cubic
# 15 cubic
# 14 thin_plate_spline
# 19 quintic
# 19 cubic
# 19 cubic
# 8 multiquadric
# 18 multiquadric
# 7 multiquadric
# 13 cubic
# 7 multiquadric
# 19 thin_plate_spline
# 10 cubic
# 15 cubic
# 19 multiquadric
# 16 cubic
# 19 cubic
# 19 cubic
# 19 cubic
# 11 thin_plate_spline
# 16 cubic
# 10 multiquadric
# 19 cubic
# 19 cubic
# 11 cubic
# 15 cubic
# 19 thin_plate_spline
# 18 cubic
# 14 thin_plate_spline
# 19 cubic
# 19 cubic
# 10 cubic
# 12 cubic
# 19 thin_plate_spline
# 17 cubic
# 11 cubic
# 7 multiquadric
# 11 cubic
# 19 cubic
# 10 cubic
# 6 multiquadric
# 19 cubic
# 19 thin_plate_spline
# 19 thin_plate_spline
# 3 multiquadric
# 11 cubic
# 10 cubic
# 10 multiquadric
# 19 cubic
# 10 multiquadric
# 18 cubic
# 19 cubic
# 15 multiquadric
# 12 cubic
# 19 thin_plate_spline
# 19 cubic
# 10 multiquadric
# 4 multiquadric
# 6 multiquadric
# 16 cubic
# 13 cubic
# 7 multiquadric
# 18 cubic
# 10 cubic
# 10 thin_plate_spline
# 10 cubic
# 19 thin_plate_spline
# 19 thin_plate_spline
# 16 thin_plate_spline
# 19 thin_plate_spline
# 19 cubic
# 15 cubic
# 14 cubic
# 13 cubic
# 19 thin_plate_spline
# 19 thin_plate_spline
# 12 cubic
# 15 cubic
# 12 cubic
# 15 cubic
# 18 thin_plate_spline
# 19 thin_plate_spline
# 17 cubic
# 18 cubic
# 15 cubic
# 5 multiquadric
# 17 cubic
# 15 cubic
# 19 thin_plate_spline
# 17 cubic
# 14 thin_plate_spline
# [(array([-0.89995885, -0.8730724 ,  0.75571581, ...,  0.3871003 ,
#           0.45742484,  0.31051499], shape=(3922,)),
#   (4, 'multiquadric'),
#   0.25878167152404785),
#  (array([ 0.26581022, -0.4215655 ,  1.1639947 , ..., -1.82597006,
#          -1.83692764, -2.03144143], shape=(3922,)),
#   (19, 'cubic'),
#   1.4295992851257324),
#  (array([-0.51999676, -0.54058415,  1.03410032, ..., -0.1876443 ,
#          -0.22709327, -0.36030039], shape=(3922,)),
#   (10, 'multiquadric'),
#   0.59897780418396),
#  (array([-0.53865041,  0.19160361,  0.52871071, ..., -0.42567392,
#          -0.5376607 , -0.68873975], shape=(3922,)),
#   (6, 'multiquadric'),
#   0.3343679904937744),
#  (array([-0.24634726, -0.46180439,  0.6336755 , ..., -0.11114373,
#           0.03599224, -0.29982266], shape=(3922,)),
#   (13, 'cubic'),
#   0.421372652053833),
#  (array([-1.08992964, -1.24424202,  0.73162536, ..., -0.70953728,
#          -0.89747992, -0.82286446], shape=(3922,)),
#   (11, 'cubic'),
#   0.7619407176971436),
#  (array([ 0.6214279 , -1.30026569,  0.69754653, ..., -0.35959884,
#          -0.33468436, -0.73823625], shape=(3922,)),
#   (9, 'multiquadric'),
#   0.8324480056762695),
#  (array([-0.38240643, -1.08003706,  0.37825717, ..., -1.28212269,
#          -1.46406989, -1.24945794], shape=(3922,)),
#   (10, 'cubic'),
#   0.8255922794342041),
#  (array([-0.86522163, -1.12981394, -0.54804551, ...,  0.85896341,
#           0.58984106,  0.52731558], shape=(3922,)),
#   (18, 'cubic'),
#   2.2440459728240967),
#  (array([ 0.64549777, -1.55766321,  0.85487584, ..., -0.16423862,
#          -0.35877202, -0.6024302 ], shape=(3922,)),
#   (10, 'cubic'),
#   0.5818862915039062),
#  (array([ 0.60897149, -0.15048596,  0.71851935, ...,  0.06131396,
#           0.07665212, -0.04898663], shape=(3922,)),
#   (3, 'multiquadric'),
#   0.21480369567871094),
#  (array([-0.40596118, -0.84825302,  0.92018736, ..., -0.68298856,
#          -1.02134157, -0.98538567], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   0.7511186599731445),
#  (array([ 0.25575043, -1.12681882,  1.15617477, ...,  0.50120102,
#           0.62538351,  0.23721965], shape=(3922,)),
#   (12, 'cubic'),
#   0.8460912704467773),
#  (array([-0.41271086, -1.95102275,  0.59893247, ..., -1.71298267,
#          -1.75574183, -1.90431462], shape=(3922,)),
#   (19, 'cubic'),
#   1.4845099449157715),
#  (array([-0.79713095, -1.15386368,  0.86133945, ...,  0.64291398,
#           0.56186483,  0.61910985], shape=(3922,)),
#   (10, 'cubic'),
#   0.9399547576904297),
#  (array([-0.56660574, -0.21886814,  1.03253052, ...,  0.65987772,
#           0.81956563,  0.60138952], shape=(3922,)),
#   (16, 'thin_plate_spline'),
#   0.5757231712341309),
#  (array([-0.55482037, -0.61377513, -0.72333776, ..., -0.62174236,
#          -0.5535895 , -0.74844481], shape=(3922,)),
#   (10, 'cubic'),
#   0.6223897933959961),
#  (array([-0.88942822, -0.90279647,  0.38869126, ..., -0.41933389,
#          -0.26565274, -0.66202127], shape=(3922,)),
#   (19, 'cubic'),
#   2.1418662071228027),
#  (array([-0.77777264, -1.3761283 ,  0.95922424, ...,  0.07153548,
#          -0.05353331, -0.25337273], shape=(3922,)),
#   (15, 'cubic'),
#   1.7293837070465088),
#  (array([-0.53824358, -0.64379588,  0.73121097, ..., -0.65896376,
#          -0.61875625, -0.75847539], shape=(3922,)),
#   (7, 'multiquadric'),
#   0.4289717674255371),
#  (array([ 0.32135504, -1.5065506 ,  0.07316312, ...,  0.24027635,
#           0.25456646, -0.11935858], shape=(3922,)),
#   (15, 'cubic'),
#   0.7093727588653564),
#  (array([-0.51685665, -1.46754399,  1.01486722, ..., -0.00802844,
#          -0.43989618, -0.90296507], shape=(3922,)),
#   (19, 'cubic'),
#   0.5708317756652832),
#  (array([ 0.3542857 , -1.03673166,  0.59199932, ..., -0.73030727,
#          -0.94090998, -1.21802318], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   0.583716630935669),
#  (array([-0.13828875, -0.76378908, -0.46790538, ..., -0.77853269,
#          -0.99247864, -1.17793946], shape=(3922,)),
#   (15, 'cubic'),
#   1.5657737255096436),
#  (array([-0.40229578, -0.43918738,  0.397763  , ...,  0.27954203,
#           0.30068566,  0.106789  ], shape=(3922,)),
#   (18, 'thin_plate_spline'),
#   0.5074009895324707),
#  (array([-1.09710916, -0.0948123 ,  0.10120608, ..., -1.96726898,
#          -1.96975282, -2.17325418], shape=(3922,)),
#   (10, 'cubic'),
#   0.6026120185852051),
#  (array([-0.66253695, -1.07213943,  0.1866733 , ..., -0.83490464,
#          -0.64696097, -0.38634083], shape=(3922,)),
#   (19, 'cubic'),
#   1.4108104705810547),
#  (array([-0.03003266, -0.33801987,  1.08238459, ...,  0.73912227,
#           1.15203209,  1.06822918], shape=(3922,)),
#   (14, 'thin_plate_spline'),
#   1.5599002838134766),
#  (array([-0.51021358, -0.93241038,  0.11770548, ..., -0.79839058,
#          -1.10024326, -0.9597479 ], shape=(3922,)),
#   (18, 'cubic'),
#   1.8374710083007812),
#  (array([-0.04712772,  0.58843815,  0.37077288, ..., -0.32757453,
#          -0.27307078, -0.3397061 ], shape=(3922,)),
#   (11, 'multiquadric'),
#   1.1208891868591309),
#  (array([-0.55768539, -0.94148507, -0.04724079, ...,  0.30761607,
#           0.43087507,  0.18719712], shape=(3922,)),
#   (13, 'cubic'),
#   1.3689405918121338),
#  (array([-0.40381753, -0.18844916,  0.49446293, ..., -0.57393956,
#          -0.62153445, -0.54923849], shape=(3922,)),
#   (8, 'multiquadric'),
#   0.7832074165344238),
#  (array([-0.78209211,  0.112067  ,  1.07822713, ..., -1.45296686,
#          -1.52512426, -1.6257828 ], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   2.2722725868225098),
#  (array([-1.02885349, -1.0990598 ,  1.18319101, ..., -0.55882535,
#          -0.59499842, -0.83502175], shape=(3922,)),
#   (19, 'cubic'),
#   1.4381146430969238),
#  (array([-0.71755649, -0.86658706,  0.44723171, ..., -0.62696536,
#          -0.7516121 , -1.08168478], shape=(3922,)),
#   (19, 'cubic'),
#   1.154416799545288),
#  (array([-0.60645988, -1.14012114,  0.24703428, ..., -0.63252278,
#          -0.5679527 , -0.50250298], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   1.0647099018096924),
#  (array([-0.4830065 , -0.32765367,  0.58674719, ...,  0.44167371,
#           0.68420055,  0.49540824], shape=(3922,)),
#   (7, 'multiquadric'),
#   0.846228837966919),
#  (array([-0.3211398 , -0.39238903,  0.78056869, ..., -0.63221283,
#          -0.35838862, -0.54018298], shape=(3922,)),
#   (16, 'cubic'),
#   0.8888990879058838),
#  (array([-0.50984695, -0.73371984,  0.90802442, ..., -1.63925671,
#          -1.56489123, -1.86317627], shape=(3922,)),
#   (19, 'cubic'),
#   1.4532277584075928),
#  (array([ 0.44367401, -0.76285104,  1.11347218, ...,  1.08398114,
#           1.29081004,  1.19593258], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   0.5590579509735107),
#  (array([-0.79968169, -1.10540893,  0.64436828, ..., -0.36455809,
#          -0.36740913, -0.93454542], shape=(3922,)),
#   (16, 'cubic'),
#   1.6983230113983154),
#  (array([ 0.59014123, -1.2114487 ,  0.09143499, ...,  0.06900473,
#           0.10593812,  0.0927148 ], shape=(3922,)),
#   (5, 'multiquadric'),
#   0.11060404777526855),
#  (array([-0.19443627,  0.2839106 ,  0.16378811, ..., -0.05849403,
#           0.0101203 ,  0.03056997], shape=(3922,)),
#   (15, 'multiquadric'),
#   0.7403764724731445),
#  (array([-0.52182579, -0.90899795,  0.40884253, ..., -0.71150624,
#          -0.71015869, -0.67789536], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   1.6372430324554443),
#  (array([-0.60902592, -1.59967188,  1.16463097, ..., -0.17597504,
#          -0.51633839, -0.58289972], shape=(3922,)),
#   (15, 'cubic'),
#   0.3820230960845947),
#  (array([-0.06137559, -1.18506952,  0.49941737, ...,  0.4769966 ,
#           0.62305051,  0.40644214], shape=(3922,)),
#   (16, 'cubic'),
#   1.5519750118255615),
#  (array([ 0.0351088 , -0.89152252,  0.19490471, ...,  0.54186713,
#           0.78801062,  0.59087407], shape=(3922,)),
#   (11, 'cubic'),
#   0.9188227653503418),
#  (array([-0.28399953, -0.61032456,  1.01694317, ..., -0.66535548,
#          -0.97113313, -1.12779324], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   1.123277187347412),
#  (array([-0.12489622, -0.57375145, -0.38487867, ..., -0.80599049,
#          -0.68925619, -0.69183983], shape=(3922,)),
#   (12, 'cubic'),
#   0.3525862693786621),
#  (array([-0.47186506, -0.56550695, -1.21247382, ..., -0.64779741,
#          -0.52094166, -0.64991182], shape=(3922,)),
#   (11, 'thin_plate_spline'),
#   1.3242695331573486),
#  (array([-0.28412125, -0.76706011,  0.03198618, ...,  0.47090717,
#           0.3366713 , -0.0014416 ], shape=(3922,)),
#   (19, 'cubic'),
#   2.0457510948181152),
#  (array([-0.36010205, -0.511052  ,  1.22155251, ..., -1.19475332,
#          -1.19115825, -1.56526377], shape=(3922,)),
#   (18, 'cubic'),
#   1.0270209312438965),
#  (array([-0.52122217, -1.9322962 ,  0.74724859, ..., -0.26444054,
#          -0.3124136 , -0.83509545], shape=(3922,)),
#   (12, 'cubic'),
#   0.6753027439117432),
#  (array([-0.47913934, -0.39046906,  0.58265603, ..., -0.08873824,
#           0.13613335, -0.06658469], shape=(3922,)),
#   (18, 'multiquadric'),
#   1.8593297004699707),
#  (array([-0.5563006 , -1.22206555,  0.80646229, ..., -0.13035922,
#          -0.26508802, -0.43952417], shape=(3922,)),
#   (11, 'cubic'),
#   0.7065439224243164),
#  (array([-0.61847345, -0.08823991,  0.27069252, ..., -0.0892125 ,
#           0.08048373, -0.42061807], shape=(3922,)),
#   (17, 'cubic'),
#   0.4753744602203369),
#  (array([ 1.28632744, -0.80309153, -0.33811922, ..., -1.36507004,
#          -1.28723821, -1.56197592], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   1.069901704788208),
#  (array([-0.01222117, -1.26751445,  0.72603141, ..., -0.13427124,
#          -0.39273599, -0.63187591], shape=(3922,)),
#   (16, 'cubic'),
#   2.400296211242676),
#  (array([-0.66295755, -0.20603315,  0.98256381, ..., -0.71007068,
#          -0.23853019, -0.66456316], shape=(3922,)),
#   (19, 'cubic'),
#   1.1663975715637207),
#  (array([-0.5923111 , -0.27909079,  1.12698115, ...,  0.67101109,
#           0.91121523,  0.55851972], shape=(3922,)),
#   (18, 'cubic'),
#   2.0695924758911133),
#  (array([-0.00127467,  1.0175776 ,  0.9159302 , ...,  0.30300856,
#           0.42978822,  0.21120202], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   1.4090206623077393),
#  (array([ 0.17663345, -1.26956532,  1.02069455, ..., -1.54998565,
#          -1.58580862, -1.65984971], shape=(3922,)),
#   (10, 'multiquadric'),
#   0.623276948928833),
#  (array([-0.72466975, -0.55868437,  0.60949615, ..., -2.01427286,
#          -1.82991845, -2.01949571], shape=(3922,)),
#   (19, 'cubic'),
#   1.7038581371307373),
#  (array([ 0.04802169,  0.05077538,  0.56544138, ..., -0.58953057,
#          -0.63017068, -0.56402009], shape=(3922,)),
#   (7, 'multiquadric'),
#   0.6087045669555664),
#  (array([-0.43341041, -1.18412445,  0.45935983, ..., -0.74295215,
#          -0.96646719, -0.98184913], shape=(3922,)),
#   (15, 'cubic'),
#   1.02297043800354),
#  (array([-0.45526432, -1.72020666, -0.62821654, ..., -0.49611673,
#          -0.46854736, -1.02934528], shape=(3922,)),
#   (15, 'cubic'),
#   0.4729654788970947),
#  (array([-0.32161428, -0.65270744,  0.99760881, ..., -0.28957583,
#          -0.16055798, -0.39287777], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   2.121095895767212),
#  (array([ 1.06465847, -0.73071025,  0.5112029 , ..., -0.24498662,
#          -0.42522276, -0.64770378], shape=(3922,)),
#   (14, 'thin_plate_spline'),
#   0.35091280937194824),
#  (array([-0.45624294, -0.73775651,  0.93644187, ..., -0.20555803,
#          -0.81067287, -0.53870235], shape=(3922,)),
#   (14, 'cubic'),
#   0.7862770557403564),
#  (array([-0.80315174, -0.83158542,  0.8018238 , ...,  0.8625537 ,
#           0.82396202,  0.71179031], shape=(3922,)),
#   (10, 'cubic'),
#   0.5592877864837646),
#  (array([-0.37628689,  0.09073872,  1.09713931, ..., -1.98981647,
#          -1.78220599, -1.94212262], shape=(3922,)),
#   (19, 'cubic'),
#   1.6362521648406982),
#  (array([-0.66756848, -1.12174265, -0.03413741, ..., -0.64249154,
#          -0.54609391, -0.68300654], shape=(3922,)),
#   (11, 'multiquadric'),
#   1.1612141132354736),
#  (array([-1.01534675, -1.33989812,  1.03481039, ...,  0.16097436,
#           0.14795417, -0.15043461], shape=(3922,)),
#   (14, 'cubic'),
#   1.6372647285461426),
#  (array([-0.53396842, -0.0888356 ,  0.06675592, ..., -0.10154143,
#          -0.19920277, -0.39500313], shape=(3922,)),
#   (15, 'cubic'),
#   0.5261085033416748),
#  (array([-0.83882163, -0.10155281,  0.88827924, ..., -1.59667205,
#          -1.62700883, -1.69502146], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   2.16086745262146),
#  (array([ 0.16821344, -0.75231191, -0.02997217, ..., -0.25419478,
#          -0.35000579, -0.83139806], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   0.5407156944274902),
#  (array([-0.0440484 ,  0.2138063 ,  1.22315556, ..., -0.17056859,
#          -0.184129  , -0.47004215], shape=(3922,)),
#   (17, 'cubic'),
#   0.4509391784667969),
#  (array([-0.77511507, -1.63177031,  0.81102579, ..., -0.7425269 ,
#          -0.58179207, -0.97581219], shape=(3922,)),
#   (19, 'quintic'),
#   2.324756383895874),
#  (array([-0.28915327, -1.11658712,  0.15193398, ..., -0.955723  ,
#          -0.81420662, -0.96321701], shape=(3922,)),
#   (19, 'multiquadric'),
#   1.5768260955810547),
#  (array([-1.11347264, -1.18265313,  0.84567107, ..., -0.6302078 ,
#          -0.70768   , -1.02830425], shape=(3922,)),
#   (12, 'cubic'),
#   0.6875886917114258),
#  (array([-1.13616143, -0.84631695,  0.60067706, ..., -0.60877866,
#          -0.76083751, -0.81864172], shape=(3922,)),
#   (15, 'cubic'),
#   0.40829944610595703),
#  (array([-0.54662468, -0.41209062,  1.13856997, ...,  0.15517708,
#           0.19071336, -0.20242227], shape=(3922,)),
#   (17, 'cubic'),
#   1.0096335411071777),
#  (array([ 1.41421512, -0.15400167,  0.84745106, ..., -0.06356038,
#          -0.01580018, -0.28701704], shape=(3922,)),
#   (19, 'cubic'),
#   1.0723998546600342),
#  (array([-1.08967813, -1.27087381,  0.59235807, ..., -1.552465  ,
#          -1.4607587 , -1.69110427], shape=(3922,)),
#   (10, 'thin_plate_spline'),
#   0.5205419063568115),
#  (array([-0.58487608, -0.73747022,  0.42983618, ..., -0.14824183,
#          -0.31545353, -0.46380796], shape=(3922,)),
#   (6, 'multiquadric'),
#   0.34661006927490234),
#  (array([-0.29559858, -0.8115199 ,  0.46286505, ...,  0.03881782,
#          -0.09871474, -0.29560364], shape=(3922,)),
#   (10, 'multiquadric'),
#   0.5218822956085205),
#  (array([-0.08526456,  0.8495866 , -0.53715693, ..., -0.78501349,
#          -0.7403735 , -1.20482226], shape=(3922,)),
#   (18, 'cubic'),
#   0.7951719760894775),
#  (array([-0.28328392, -0.14541012,  0.39582186, ..., -0.33843016,
#          -0.16209981, -0.41591531], shape=(3922,)),
#   (5, 'multiquadric'),
#   0.3140695095062256),
#  (array([-1.04981726, -0.84558853,  1.2154813 , ..., -0.95656456,
#          -0.96123594, -1.03483606], shape=(3922,)),
#   (3, 'multiquadric'),
#   0.45413708686828613),
#  (array([-0.3841454 ,  0.34396484,  0.44691472, ...,  0.35288553,
#           0.18432217,  0.23148326], shape=(3922,)),
#   (18, 'cubic'),
#   0.4915041923522949),
#  (array([-0.0532723 , -1.0635798 , -0.40470534, ...,  0.4187621 ,
#           0.51337831,  0.49078011], shape=(3922,)),
#   (7, 'multiquadric'),
#   0.40876197814941406),
#  (array([-0.24033895, -0.45597795,  0.57072053, ...,  0.05994491,
#           0.23993945, -0.03306688], shape=(3922,)),
#   (19, 'cubic'),
#   1.186659812927246),
#  (array([-0.69887048, -1.62316165,  0.93586709, ..., -1.18383528,
#          -1.1683586 , -1.19845837], shape=(3922,)),
#   (19, 'thin_plate_spline'),
#   0.5975978374481201),
#  (array([-0.68232849, -1.09635765,  1.20217836, ..., -1.28614497,
#          -1.223795  , -1.63417062], shape=(3922,)),
#   (11, 'cubic'),
#   0.7421412467956543),
#  (array([ 1.0407391 , -1.74011614,  0.72100089, ..., -0.30470307,
#          -0.43267369, -0.87886683], shape=(3922,)),
#   (15, 'cubic'),
#   1.5943758487701416),
#  (array([-0.57575293, -0.77546834,  1.18948878, ...,  0.45336639,
#           0.4136903 ,  0.0616185 ], shape=(3922,)),
#   (13, 'cubic'),
#   0.7488012313842773),
#  (array([-0.85782661, -1.04299931,  0.92569416, ..., -0.60424789,
#          -0.66481798, -1.05561111], shape=(3922,)),
#   (19, 'cubic'),
#   0.8849997520446777),
#  (array([-0.509221  , -0.67826683,  0.46566957, ..., -0.77789798,
#          -0.97024742, -1.09230059], shape=(3922,)),
#   (14, 'thin_plate_spline'),
#   1.0358262062072754),
#  (array([ 0.23301025, -1.59027197,  0.3518468 , ..., -1.47738611,
#          -1.71720805, -1.82408685], shape=(3922,)),
#   (17, 'cubic'),
#   0.40296006202697754),
#  (array([-0.57913149, -0.61077596,  0.65053353, ..., -0.32265608,
#          -0.41838782, -0.73342776], shape=(3922,)),
#   (10, 'multiquadric'),
#   0.5471339225769043)]

# %%
rslt
# Out:
# Parallel(n_jobs=100)
